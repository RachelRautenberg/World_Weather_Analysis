# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
import requests

# Import the API key
from API_config import weather_api_key

# starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# Import the datetime module from the datetime library
import time
from datetime import datetime

type(url)
# Out:
# str

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval          ")
print("------------------------          ")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create the endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d   %H:%M:%S")
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat, 
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                          "Country": city_country,
                         "Weather Description": weather_description})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate the data loading is complete.
print("-----------------------------")
print("   Data Retrieval Complete   ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of set 1 | qaanaaq
# Processing Record 2 of set 1 | coihaique
# Processing Record 3 of set 1 | geraldton
# Processing Record 4 of set 1 | bredasdorp
# Processing Record 5 of set 1 | barinas
# Processing Record 6 of set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of set 1 | derzhavinsk
# Processing Record 8 of set 1 | lorengau
# Processing Record 9 of set 1 | sinnamary
# Processing Record 10 of set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of set 1 | aleksandrovskoye
# Processing Record 12 of set 1 | kaitangata
# Processing Record 13 of set 1 | ushuaia
# Processing Record 14 of set 1 | shimoda
# Processing Record 15 of set 1 | dikson
# Processing Record 16 of set 1 | sao jose da coroa grande
# Processing Record 17 of set 1 | bengkulu
# Processing Record 18 of set 1 | arraial do cabo
# Processing Record 19 of set 1 | mataura
# Processing Record 20 of set 1 | atuona
# Processing Record 21 of set 1 | xinqing
# Processing Record 22 of set 1 | rikitea
# Processing Record 23 of set 1 | muli
# Processing Record 24 of set 1 | bluff
# Processing Record 25 of set 1 | hithadhoo
# Processing Record 26 of set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of set 1 | port hedland
# Processing Record 28 of set 1 | albany
# Processing Record 29 of set 1 | avarua
# Processing Record 30 of set 1 | puerto ayora
# Processing Record 31 of set 1 | kapaa
# Processing Record 32 of set 1 | raudeberg
# Processing Record 33 of set 1 | phan thiet
# Processing Record 34 of set 1 | hobart
# Processing Record 35 of set 1 | salalah
# Processing Record 36 of set 1 | grand gaube
# Processing Record 37 of set 1 | punta arenas
# Processing Record 38 of set 1 | coquimbo
# Processing Record 39 of set 1 | ribeira grande
# Processing Record 40 of set 1 | cherskiy
# Processing Record 41 of set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of set 1 | acapulco
# Processing Record 43 of set 1 | yellowknife
# Processing Record 44 of set 1 | upernavik
# Processing Record 45 of set 1 | guerrero negro
# Processing Record 46 of set 1 | tsihombe
# City not found. Skipping...
# Processing Record 47 of set 1 | jamestown
# Processing Record 48 of set 1 | port alfred
# Processing Record 49 of set 1 | katsuura
# Processing Record 50 of set 1 | santa cruz
# Processing Record 1 of set 2 | new norfolk
# Processing Record 2 of set 2 | vicuna
# Processing Record 3 of set 2 | saldanha
# Processing Record 4 of set 2 | barrow
# Processing Record 5 of set 2 | archidona
# Processing Record 6 of set 2 | kletskaya
# Processing Record 7 of set 2 | iquitos
# Processing Record 8 of set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of set 2 | bardiyah
# Processing Record 10 of set 2 | nabire
# Processing Record 11 of set 2 | kodiak
# Processing Record 12 of set 2 | touros
# Processing Record 13 of set 2 | sumisip
# Processing Record 14 of set 2 | sa kaeo
# Processing Record 15 of set 2 | mar del plata
# Processing Record 16 of set 2 | narsaq
# Processing Record 17 of set 2 | lompoc
# Processing Record 18 of set 2 | opotiki
# Processing Record 19 of set 2 | satitoa
# City not found. Skipping...
# Processing Record 20 of set 2 | garowe
# Processing Record 21 of set 2 | esmeraldas
# Processing Record 22 of set 2 | pucallpa
# Processing Record 23 of set 2 | peniche
# Processing Record 24 of set 2 | auki
# Processing Record 25 of set 2 | sitka
# Processing Record 26 of set 2 | gorno-altaysk
# Processing Record 27 of set 2 | airai
# Processing Record 28 of set 2 | mikuni
# Processing Record 29 of set 2 | jiangyou
# Processing Record 30 of set 2 | villacarrillo
# Processing Record 31 of set 2 | bethel
# Processing Record 32 of set 2 | jumla
# Processing Record 33 of set 2 | san fernando
# Processing Record 34 of set 2 | charters towers
# Processing Record 35 of set 2 | east london
# Processing Record 36 of set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of set 2 | tautira
# Processing Record 38 of set 2 | sao filipe
# Processing Record 39 of set 2 | ilulissat
# Processing Record 40 of set 2 | khatanga
# Processing Record 41 of set 2 | beringovskiy
# Processing Record 42 of set 2 | maldonado
# Processing Record 43 of set 2 | vaini
# Processing Record 44 of set 2 | thompson
# Processing Record 45 of set 2 | the valley
# Processing Record 46 of set 2 | nara
# Processing Record 47 of set 2 | hasaki
# Processing Record 48 of set 2 | aklavik
# Processing Record 49 of set 2 | provideniya
# Processing Record 50 of set 2 | hilo
# Processing Record 1 of set 3 | mokhotlong
# Processing Record 2 of set 3 | la ronge
# Processing Record 3 of set 3 | busselton
# Processing Record 4 of set 3 | ust-maya
# Processing Record 5 of set 3 | norman wells
# Processing Record 6 of set 3 | laguna
# Processing Record 7 of set 3 | gazanjyk
# Processing Record 8 of set 3 | belyy yar
# Processing Record 9 of set 3 | chalons-en-champagne
# Processing Record 10 of set 3 | saskylakh
# Processing Record 11 of set 3 | butaritari
# Processing Record 12 of set 3 | damaturu
# Processing Record 13 of set 3 | aleksandrov gay
# Processing Record 14 of set 3 | dzerzhinsk
# Processing Record 15 of set 3 | clyde river
# Processing Record 16 of set 3 | nador
# Processing Record 17 of set 3 | tieli
# Processing Record 18 of set 3 | iaciara
# Processing Record 19 of set 3 | port elizabeth
# Processing Record 20 of set 3 | qasigiannguit
# Processing Record 21 of set 3 | leningradskiy
# Processing Record 22 of set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of set 3 | bida
# Processing Record 25 of set 3 | caravelas
# Processing Record 26 of set 3 | hajnowka
# Processing Record 27 of set 3 | buala
# Processing Record 28 of set 3 | praia da vitoria
# Processing Record 29 of set 3 | isangel
# Processing Record 30 of set 3 | thai binh
# Processing Record 31 of set 3 | carnarvon
# Processing Record 32 of set 3 | walvis bay
# Processing Record 33 of set 3 | dwarka
# Processing Record 34 of set 3 | iqaluit
# Processing Record 35 of set 3 | ulladulla
# Processing Record 36 of set 3 | nouakchott
# Processing Record 37 of set 3 | pevek
# Processing Record 38 of set 3 | kalangala
# Processing Record 39 of set 3 | leh
# Processing Record 40 of set 3 | kalmunai
# Processing Record 41 of set 3 | tecoanapa
# Processing Record 42 of set 3 | hermanus
# Processing Record 43 of set 3 | qui nhon
# Processing Record 44 of set 3 | hirado
# Processing Record 45 of set 3 | lebu
# Processing Record 46 of set 3 | klyuchi
# Processing Record 47 of set 3 | esperance
# Processing Record 48 of set 3 | erenhot
# Processing Record 49 of set 3 | furano
# Processing Record 50 of set 3 | castro
# Processing Record 1 of set 4 | tefe
# Processing Record 2 of set 4 | urusha
# Processing Record 3 of set 4 | tchaourou
# Processing Record 4 of set 4 | darhan
# Processing Record 5 of set 4 | aksu
# Processing Record 6 of set 4 | powell river
# Processing Record 7 of set 4 | catuday
# Processing Record 8 of set 4 | gat
# Processing Record 9 of set 4 | ust-kulom
# Processing Record 10 of set 4 | whitianga
# Processing Record 11 of set 4 | abu dhabi
# Processing Record 12 of set 4 | demir kapija
# Processing Record 13 of set 4 | tuktoyaktuk
# Processing Record 14 of set 4 | tiksi
# Processing Record 15 of set 4 | mahebourg
# Processing Record 16 of set 4 | pangnirtung
# Processing Record 17 of set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of set 4 | quatre cocos
# Processing Record 19 of set 4 | adamovka
# Processing Record 20 of set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of set 4 | thano bula khan
# City not found. Skipping...
# Processing Record 22 of set 4 | oistins
# Processing Record 23 of set 4 | hovd
# Processing Record 24 of set 4 | sabang
# Processing Record 25 of set 4 | saleaula
# City not found. Skipping...
# Processing Record 26 of set 4 | nikolskoye
# Processing Record 27 of set 4 | marcona
# City not found. Skipping...
# Processing Record 28 of set 4 | cape town
# Processing Record 29 of set 4 | mendahara
# City not found. Skipping...
# Processing Record 30 of set 4 | santa maria
# Processing Record 31 of set 4 | taolanaro
# City not found. Skipping...
# Processing Record 32 of set 4 | talah
# City not found. Skipping...
# Processing Record 33 of set 4 | san pedro de lloc
# Processing Record 34 of set 4 | menongue
# Processing Record 35 of set 4 | tasiilaq
# Processing Record 36 of set 4 | brainerd
# Processing Record 37 of set 4 | bambous virieux
# Processing Record 38 of set 4 | sechura
# Processing Record 39 of set 4 | kavaratti
# Processing Record 40 of set 4 | pulandian
# Processing Record 41 of set 4 | mechetinskaya
# Processing Record 42 of set 4 | kavieng
# Processing Record 43 of set 4 | vestmanna
# Processing Record 44 of set 4 | makakilo city
# Processing Record 45 of set 4 | constitucion
# Processing Record 46 of set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of set 4 | georgetown
# Processing Record 48 of set 4 | hirara
# Processing Record 49 of set 4 | saint george
# Processing Record 50 of set 4 | chuy
# Processing Record 1 of set 5 | hidrolandia
# Processing Record 2 of set 5 | jingdezhen
# Processing Record 3 of set 5 | qinzhou
# Processing Record 4 of set 5 | warrnambool
# Processing Record 5 of set 5 | mayumba
# Processing Record 6 of set 5 | te anau
# Processing Record 7 of set 5 | harper
# Processing Record 8 of set 5 | pakxan
# Processing Record 9 of set 5 | vila franca do campo
# Processing Record 10 of set 5 | trinidad
# Processing Record 11 of set 5 | ancud
# Processing Record 12 of set 5 | worthington
# Processing Record 13 of set 5 | petropavlovka
# Processing Record 14 of set 5 | ussel
# Processing Record 15 of set 5 | sur
# Processing Record 16 of set 5 | mongo
# Processing Record 17 of set 5 | yulara
# Processing Record 18 of set 5 | camacha
# Processing Record 19 of set 5 | alice springs
# Processing Record 20 of set 5 | monywa
# Processing Record 21 of set 5 | kirakira
# Processing Record 22 of set 5 | doha
# Processing Record 23 of set 5 | luderitz
# Processing Record 24 of set 5 | khani
# Processing Record 25 of set 5 | horezu
# Processing Record 26 of set 5 | foix
# Processing Record 27 of set 5 | sabha
# Processing Record 28 of set 5 | nurobod
# Processing Record 29 of set 5 | flinders
# Processing Record 30 of set 5 | dujuma
# City not found. Skipping...
# Processing Record 31 of set 5 | valparaiso
# Processing Record 32 of set 5 | port lincoln
# Processing Record 33 of set 5 | rongcheng
# Processing Record 34 of set 5 | yambio
# Processing Record 35 of set 5 | ponta do sol
# Processing Record 36 of set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of set 5 | honiara
# Processing Record 38 of set 5 | adelaide
# Processing Record 39 of set 5 | amderma
# City not found. Skipping...
# Processing Record 40 of set 5 | tessalit
# Processing Record 41 of set 5 | belmonte
# Processing Record 42 of set 5 | avera
# Processing Record 43 of set 5 | woodward
# Processing Record 44 of set 5 | grand river south east
# City not found. Skipping...
# Processing Record 45 of set 5 | half moon bay
# Processing Record 46 of set 5 | chokurdakh
# Processing Record 47 of set 5 | cabo san lucas
# Processing Record 48 of set 5 | torbay
# Processing Record 49 of set 5 | cockburn town
# Processing Record 50 of set 5 | mayo
# Processing Record 1 of set 6 | alofi
# Processing Record 2 of set 6 | shitanjing
# Processing Record 3 of set 6 | boa vista
# Processing Record 4 of set 6 | phalaborwa
# Processing Record 5 of set 6 | eureka
# Processing Record 6 of set 6 | vasilyevo
# Processing Record 7 of set 6 | tuatapere
# Processing Record 8 of set 6 | hunza
# City not found. Skipping...
# Processing Record 9 of set 6 | conway
# Processing Record 10 of set 6 | homestead
# Processing Record 11 of set 6 | lephepe
# City not found. Skipping...
# Processing Record 12 of set 6 | sobolevo
# Processing Record 13 of set 6 | verkh-usugli
# Processing Record 14 of set 6 | rio grande
# Processing Record 15 of set 6 | linxia
# Processing Record 16 of set 6 | moose factory
# Processing Record 17 of set 6 | kichera
# Processing Record 18 of set 6 | kulhudhuffushi
# Processing Record 19 of set 6 | vardo
# Processing Record 20 of set 6 | greenwood
# Processing Record 21 of set 6 | quesnel
# Processing Record 22 of set 6 | tucuman
# Processing Record 23 of set 6 | kushima
# Processing Record 24 of set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of set 6 | nsanje
# Processing Record 26 of set 6 | nanortalik
# Processing Record 27 of set 6 | grindavik
# Processing Record 28 of set 6 | wexford
# Processing Record 29 of set 6 | pahrump
# Processing Record 30 of set 6 | sibu
# Processing Record 31 of set 6 | baijiantan
# Processing Record 32 of set 6 | tupiza
# Processing Record 33 of set 6 | cuenca
# Processing Record 34 of set 6 | marzuq
# Processing Record 35 of set 6 | ixtapa
# Processing Record 36 of set 6 | mitsamiouli
# Processing Record 37 of set 6 | haukipudas
# Processing Record 38 of set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of set 6 | fairbanks
# Processing Record 40 of set 6 | stykkisholmur
# Processing Record 41 of set 6 | luxor
# Processing Record 42 of set 6 | voh
# Processing Record 43 of set 6 | kutum
# Processing Record 44 of set 6 | udachnyy
# Processing Record 45 of set 6 | tomatlan
# Processing Record 46 of set 6 | kars
# Processing Record 47 of set 6 | husavik
# Processing Record 48 of set 6 | simpang empat
# Processing Record 49 of set 6 | polson
# Processing Record 50 of set 6 | coxim
# Processing Record 1 of set 7 | asau
# Processing Record 2 of set 7 | kupino
# Processing Record 3 of set 7 | hami
# Processing Record 4 of set 7 | laguna de perlas
# Processing Record 5 of set 7 | joshimath
# Processing Record 6 of set 7 | cayenne
# Processing Record 7 of set 7 | caborca
# Processing Record 8 of set 7 | sola
# Processing Record 9 of set 7 | baherden
# Processing Record 10 of set 7 | deputatskiy
# Processing Record 11 of set 7 | sebrovo
# Processing Record 12 of set 7 | mbandaka
# Processing Record 13 of set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 14 of set 7 | la brea
# Processing Record 15 of set 7 | urumqi
# Processing Record 16 of set 7 | mao
# Processing Record 17 of set 7 | tyup
# Processing Record 18 of set 7 | fuling
# Processing Record 19 of set 7 | talnakh
# Processing Record 20 of set 7 | of
# City not found. Skipping...
# Processing Record 21 of set 7 | skalistyy
# City not found. Skipping...
# Processing Record 22 of set 7 | katherine
# Processing Record 23 of set 7 | maumere
# Processing Record 24 of set 7 | virginia beach
# Processing Record 25 of set 7 | sheridan
# Processing Record 26 of set 7 | kloulklubed
# Processing Record 27 of set 7 | arman
# Processing Record 28 of set 7 | manggar
# Processing Record 29 of set 7 | mtambile
# Processing Record 30 of set 7 | eenhana
# Processing Record 31 of set 7 | ardakan
# Processing Record 32 of set 7 | faanui
# Processing Record 33 of set 7 | salinas
# Processing Record 34 of set 7 | malmyzh
# Processing Record 35 of set 7 | ostrovnoy
# Processing Record 36 of set 7 | pachino
# Processing Record 37 of set 7 | verkhoyansk
# Processing Record 38 of set 7 | souillac
# Processing Record 39 of set 7 | estepa
# Processing Record 40 of set 7 | maniitsoq
# Processing Record 41 of set 7 | degollado
# Processing Record 42 of set 7 | yeppoon
# Processing Record 43 of set 7 | eyl
# Processing Record 44 of set 7 | linhares
# Processing Record 45 of set 7 | itarema
# Processing Record 46 of set 7 | remanso
# Processing Record 47 of set 7 | nerchinskiy zavod
# Processing Record 48 of set 7 | ayan
# Processing Record 49 of set 7 | san patricio
# Processing Record 50 of set 7 | acajutla
# Processing Record 1 of set 8 | bang saphan
# Processing Record 2 of set 8 | bani
# Processing Record 3 of set 8 | saint-philippe
# Processing Record 4 of set 8 | komsomolskiy
# Processing Record 5 of set 8 | bharatpur
# Processing Record 6 of set 8 | faya
# Processing Record 7 of set 8 | khorixas
# Processing Record 8 of set 8 | ucluelet
# Processing Record 9 of set 8 | ust-kuyga
# Processing Record 10 of set 8 | melito di porto salvo
# Processing Record 11 of set 8 | rutland
# Processing Record 12 of set 8 | sorvag
# City not found. Skipping...
# Processing Record 13 of set 8 | nesterov
# Processing Record 14 of set 8 | vila velha
# Processing Record 15 of set 8 | sosnovo-ozerskoye
# Processing Record 16 of set 8 | takhli
# Processing Record 17 of set 8 | havoysund
# Processing Record 18 of set 8 | socorro
# Processing Record 19 of set 8 | svetlogorsk
# Processing Record 20 of set 8 | ceres
# Processing Record 21 of set 8 | hamilton
# Processing Record 22 of set 8 | mokhsogollokh
# Processing Record 23 of set 8 | dauriya
# Processing Record 24 of set 8 | karauzyak
# City not found. Skipping...
# Processing Record 25 of set 8 | simao
# Processing Record 26 of set 8 | igarka
# Processing Record 27 of set 8 | port hardy
# Processing Record 28 of set 8 | atar
# Processing Record 29 of set 8 | lagoa
# Processing Record 30 of set 8 | nurpur
# Processing Record 31 of set 8 | lethem
# Processing Record 32 of set 8 | cervo
# Processing Record 33 of set 8 | nikolayevka
# Processing Record 34 of set 8 | ewa beach
# Processing Record 35 of set 8 | san joaquin
# Processing Record 36 of set 8 | shanghai
# Processing Record 37 of set 8 | brive-la-gaillarde
# Processing Record 38 of set 8 | meulaboh
# Processing Record 39 of set 8 | yoichi
# Processing Record 40 of set 8 | puerto carreno
# Processing Record 41 of set 8 | muisne
# Processing Record 42 of set 8 | vagur
# Processing Record 43 of set 8 | carupano
# Processing Record 44 of set 8 | sao joao da barra
# Processing Record 45 of set 8 | barra do garcas
# Processing Record 46 of set 8 | kupang
# Processing Record 47 of set 8 | severo-kurilsk
# Processing Record 48 of set 8 | atka
# City not found. Skipping...
# Processing Record 49 of set 8 | gamba
# Processing Record 50 of set 8 | berlevag
# Processing Record 1 of set 9 | bria
# Processing Record 2 of set 9 | megion
# Processing Record 3 of set 9 | saint-joseph
# Processing Record 4 of set 9 | hambantota
# Processing Record 5 of set 9 | taoudenni
# Processing Record 6 of set 9 | lavrentiya
# Processing Record 7 of set 9 | batagay-alyta
# Processing Record 8 of set 9 | tortoli
# Processing Record 9 of set 9 | hualmay
# Processing Record 10 of set 9 | temuco
# Processing Record 11 of set 9 | longyearbyen
# Processing Record 12 of set 9 | ojinaga
# Processing Record 13 of set 9 | talcahuano
# Processing Record 14 of set 9 | port blair
# Processing Record 15 of set 9 | centralia
# Processing Record 16 of set 9 | sioux lookout
# Processing Record 17 of set 9 | port macquarie
# Processing Record 18 of set 9 | les cayes
# Processing Record 19 of set 9 | togur
# Processing Record 20 of set 9 | maues
# Processing Record 21 of set 9 | scarborough
# Processing Record 22 of set 9 | dale
# Processing Record 23 of set 9 | terrace bay
# Processing Record 24 of set 9 | kattivakkam
# Processing Record 25 of set 9 | fallon
# Processing Record 26 of set 9 | mount isa
# Processing Record 27 of set 9 | razumnoye
# Processing Record 28 of set 9 | nome
# Processing Record 29 of set 9 | merauke
# Processing Record 30 of set 9 | opuwo
# Processing Record 31 of set 9 | jos
# Processing Record 32 of set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 33 of set 9 | san isidro
# Processing Record 34 of set 9 | karlstad
# Processing Record 35 of set 9 | biltine
# Processing Record 36 of set 9 | egvekinot
# Processing Record 37 of set 9 | fuerte olimpo
# Processing Record 38 of set 9 | gravdal
# Processing Record 39 of set 9 | kuito
# Processing Record 40 of set 9 | sisimiut
# Processing Record 41 of set 9 | jiddah
# City not found. Skipping...
# Processing Record 42 of set 9 | kosa
# Processing Record 43 of set 9 | kungurtug
# Processing Record 44 of set 9 | lavras
# Processing Record 45 of set 9 | seoul
# Processing Record 46 of set 9 | shamkhal
# Processing Record 47 of set 9 | grabouw
# Processing Record 48 of set 9 | lakatoro
# Processing Record 49 of set 9 | puerto escondido
# Processing Record 50 of set 9 | maroantsetra
# Processing Record 1 of set 10 | noumea
# Processing Record 2 of set 10 | cabedelo
# Processing Record 3 of set 10 | pervomayskoye
# Processing Record 4 of set 10 | moerdijk
# Processing Record 5 of set 10 | khonuu
# City not found. Skipping...
# Processing Record 6 of set 10 | cidreira
# Processing Record 7 of set 10 | luau
# Processing Record 8 of set 10 | matagami
# Processing Record 9 of set 10 | college
# Processing Record 10 of set 10 | khudumelapye
# Processing Record 11 of set 10 | karibib
# Processing Record 12 of set 10 | barroualie
# City not found. Skipping...
# Processing Record 13 of set 10 | oreanda
# City not found. Skipping...
# Processing Record 14 of set 10 | sojat
# Processing Record 15 of set 10 | bonavista
# Processing Record 16 of set 10 | xining
# Processing Record 17 of set 10 | melbu
# Processing Record 18 of set 10 | somerset
# Processing Record 19 of set 10 | dingle
# Processing Record 20 of set 10 | celestun
# Processing Record 21 of set 10 | wawa
# Processing Record 22 of set 10 | medea
# Processing Record 23 of set 10 | kyra
# Processing Record 24 of set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of set 10 | klaksvik
# Processing Record 26 of set 10 | zyryanka
# Processing Record 27 of set 10 | bama
# Processing Record 28 of set 10 | krasnoselkup
# Processing Record 29 of set 10 | wanning
# Processing Record 30 of set 10 | mangrol
# Processing Record 31 of set 10 | santa vitoria do palmar
# Processing Record 32 of set 10 | kanevskaya
# Processing Record 33 of set 10 | saint-francois
# Processing Record 34 of set 10 | washington
# Processing Record 35 of set 10 | yuanping
# Processing Record 36 of set 10 | janakpur
# Processing Record 37 of set 10 | goderich
# Processing Record 38 of set 10 | micheweni
# Processing Record 39 of set 10 | nizwa
# Processing Record 40 of set 10 | diffa
# Processing Record 41 of set 10 | lata
# Processing Record 42 of set 10 | ketchikan
# Processing Record 43 of set 10 | novopokrovka
# Processing Record 44 of set 10 | srednekolymsk
# Processing Record 45 of set 10 | prata
# Processing Record 46 of set 10 | broome
# Processing Record 47 of set 10 | ballina
# Processing Record 48 of set 10 | safwah
# City not found. Skipping...
# Processing Record 49 of set 10 | victoria
# Processing Record 50 of set 10 | siderno
# Processing Record 1 of set 11 | nassau
# Processing Record 2 of set 11 | yatou
# Processing Record 3 of set 11 | podor
# Processing Record 4 of set 11 | fortuna
# Processing Record 5 of set 11 | pisco
# Processing Record 6 of set 11 | coruripe
# Processing Record 7 of set 11 | kingston
# Processing Record 8 of set 11 | nuuk
# Processing Record 9 of set 11 | honolulu
# Processing Record 10 of set 11 | shahrud
# Processing Record 11 of set 11 | debre tabor
# Processing Record 12 of set 11 | utiroa
# City not found. Skipping...
# Processing Record 13 of set 11 | san quintin
# Processing Record 14 of set 11 | saint-pierre
# Processing Record 15 of set 11 | pamanukan
# Processing Record 16 of set 11 | shu
# Processing Record 17 of set 11 | osoyoos
# Processing Record 18 of set 11 | kabalo
# Processing Record 19 of set 11 | isiro
# Processing Record 20 of set 11 | guangyuan
# Processing Record 21 of set 11 | nyurba
# Processing Record 22 of set 11 | kazerun
# Processing Record 23 of set 11 | marinskaya
# City not found. Skipping...
# Processing Record 24 of set 11 | barra patuca
# Processing Record 25 of set 11 | aksarka
# Processing Record 26 of set 11 | tingo maria
# Processing Record 27 of set 11 | inuvik
# Processing Record 28 of set 11 | mantua
# Processing Record 29 of set 11 | gizo
# Processing Record 30 of set 11 | fredonia
# Processing Record 31 of set 11 | acarau
# Processing Record 32 of set 11 | dali
# Processing Record 33 of set 11 | sao felix do xingu
# Processing Record 34 of set 11 | kargasok
# Processing Record 35 of set 11 | yelanskiy
# Processing Record 36 of set 11 | indramayu
# Processing Record 37 of set 11 | hailar
# Processing Record 38 of set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 39 of set 11 | bombay
# Processing Record 40 of set 11 | lensk
# Processing Record 41 of set 11 | newport news
# Processing Record 42 of set 11 | oppdal
# Processing Record 43 of set 11 | taiyuan
# Processing Record 44 of set 11 | vilcun
# Processing Record 45 of set 11 | santa rosalia
# Processing Record 46 of set 11 | lure
# Processing Record 47 of set 11 | abalak
# Processing Record 48 of set 11 | sinjar
# Processing Record 49 of set 11 | wahpeton
# Processing Record 50 of set 11 | verkh-neyvinskiy
# Processing Record 1 of set 12 | homer
# Processing Record 2 of set 12 | fairview
# Processing Record 3 of set 12 | nouadhibou
# Processing Record 4 of set 12 | prado
# Processing Record 5 of set 12 | balykshi
# Processing Record 6 of set 12 | dordrecht
# Processing Record 7 of set 12 | manaure
# Processing Record 8 of set 12 | peine
# Processing Record 9 of set 12 | jackson
# Processing Record 10 of set 12 | shelburne
# Processing Record 11 of set 12 | douentza
# Processing Record 12 of set 12 | warqla
# City not found. Skipping...
# Processing Record 13 of set 12 | tsabong
# Processing Record 14 of set 12 | mombetsu
# Processing Record 15 of set 12 | dabakala
# Processing Record 16 of set 12 | ndende
# Processing Record 17 of set 12 | minna
# Processing Record 18 of set 12 | mnogovershinnyy
# Processing Record 19 of set 12 | san policarpo
# Processing Record 20 of set 12 | chara
# Processing Record 21 of set 12 | saravan
# Processing Record 22 of set 12 | solenzo
# Processing Record 23 of set 12 | nishihara
# Processing Record 24 of set 12 | ossora
# Processing Record 25 of set 12 | inhapim
# Processing Record 26 of set 12 | aykhal
# Processing Record 27 of set 12 | ternate
# Processing Record 28 of set 12 | nantucket
# Processing Record 29 of set 12 | los llanos de aridane
# Processing Record 30 of set 12 | atikokan
# Processing Record 31 of set 12 | manyana
# Processing Record 32 of set 12 | chicama
# Processing Record 33 of set 12 | gelemso
# Processing Record 34 of set 12 | karlskrona
# Processing Record 35 of set 12 | saint-louis
# Processing Record 36 of set 12 | novobirilyussy
# Processing Record 37 of set 12 | dori
# Processing Record 38 of set 12 | teguise
# Processing Record 39 of set 12 | quelimane
# Processing Record 40 of set 12 | tiznit
# Processing Record 41 of set 12 | chengde
# Processing Record 42 of set 12 | bereda
# Processing Record 43 of set 12 | santa cecilia
# Processing Record 44 of set 12 | bundaberg
# Processing Record 45 of set 12 | anadyr
# Processing Record 46 of set 12 | tucupita
# Processing Record 47 of set 12 | alta floresta
# Processing Record 48 of set 12 | siguiri
# Processing Record 49 of set 12 | bilibino
# Processing Record 50 of set 12 | yamada
# Processing Record 1 of set 13 | sungaipenuh
# Processing Record 2 of set 13 | waddan
# Processing Record 3 of set 13 | sigli
# Processing Record 4 of set 13 | turayf
# Processing Record 5 of set 13 | hit
# Processing Record 6 of set 13 | fiumicino
# Processing Record 7 of set 13 | yurino
# Processing Record 8 of set 13 | walajabad
# City not found. Skipping...
# Processing Record 9 of set 13 | kjopsvik
# Processing Record 10 of set 13 | henties bay
# Processing Record 11 of set 13 | malartic
# Processing Record 12 of set 13 | thunder bay
# Processing Record 13 of set 13 | mount gambier
# Processing Record 14 of set 13 | tamiahua
# Processing Record 15 of set 13 | annau
# Processing Record 16 of set 13 | codrington
# Processing Record 17 of set 13 | fez
# Processing Record 18 of set 13 | fort nelson
# Processing Record 19 of set 13 | birjand
# Processing Record 20 of set 13 | tigil
# Processing Record 21 of set 13 | kaiserslautern
# Processing Record 22 of set 13 | karratha
# Processing Record 23 of set 13 | balud
# Processing Record 24 of set 13 | mrirt
# City not found. Skipping...
# Processing Record 25 of set 13 | tumannyy
# City not found. Skipping...
# Processing Record 26 of set 13 | warri
# Processing Record 27 of set 13 | shache
# Processing Record 28 of set 13 | ullapool
# Processing Record 29 of set 13 | karpuninskiy
# City not found. Skipping...
# Processing Record 30 of set 13 | baracoa
# Processing Record 31 of set 13 | bitung
# Processing Record 32 of set 13 | san lawrenz
# Processing Record 33 of set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of set 13 | arlit
# Processing Record 35 of set 13 | margate
# Processing Record 36 of set 13 | kirando
# Processing Record 37 of set 13 | vasilyevskiy mokh
# Processing Record 38 of set 13 | chone
# Processing Record 39 of set 13 | punta cardon
# Processing Record 40 of set 13 | northallerton
# Processing Record 41 of set 13 | saint-georges
# Processing Record 42 of set 13 | beloha
# Processing Record 43 of set 13 | lleida
# Processing Record 44 of set 13 | rungata
# City not found. Skipping...
# Processing Record 45 of set 13 | churapcha
# Processing Record 46 of set 13 | santa fe
# Processing Record 47 of set 13 | richards bay
# Processing Record 48 of set 13 | cabanas
# Processing Record 49 of set 13 | ambulu
# Processing Record 50 of set 13 | vanavara
# Processing Record 1 of set 14 | praxedis guerrero
# Processing Record 2 of set 14 | po
# City not found. Skipping...
# Processing Record 3 of set 14 | taunggyi
# Processing Record 4 of set 14 | cariamanga
# Processing Record 5 of set 14 | bogalusa
# Processing Record 6 of set 14 | kamina
# Processing Record 7 of set 14 | kidal
# Processing Record 8 of set 14 | juegang
# Processing Record 9 of set 14 | gopalpur
# Processing Record 10 of set 14 | poum
# Processing Record 11 of set 14 | anzoategui
# Processing Record 12 of set 14 | inirida
# Processing Record 13 of set 14 | uyemskiy
# Processing Record 14 of set 14 | nelson bay
# Processing Record 15 of set 14 | zhanaozen
# Processing Record 16 of set 14 | alyangula
# Processing Record 17 of set 14 | kisangani
# Processing Record 18 of set 14 | hay river
# Processing Record 19 of set 14 | bay roberts
# Processing Record 20 of set 14 | odienne
# Processing Record 21 of set 14 | marawi
# Processing Record 22 of set 14 | mahibadhoo
# Processing Record 23 of set 14 | kruisfontein
# Processing Record 24 of set 14 | pimentel
# Processing Record 25 of set 14 | kununurra
# Processing Record 26 of set 14 | gull lake
# Processing Record 27 of set 14 | saquena
# Processing Record 28 of set 14 | oussouye
# Processing Record 29 of set 14 | presidencia roque saenz pena
# Processing Record 30 of set 14 | westport
# Processing Record 31 of set 14 | zharkent
# Processing Record 32 of set 14 | pokhara
# Processing Record 33 of set 14 | selikhino
# Processing Record 34 of set 14 | kerouane
# Processing Record 35 of set 14 | sangar
# Processing Record 36 of set 14 | ninghai
# Processing Record 37 of set 14 | mandera
# Processing Record 38 of set 14 | maceio
# Processing Record 39 of set 14 | kenai
# Processing Record 40 of set 14 | milton
# Processing Record 41 of set 14 | brae
# Processing Record 42 of set 14 | seymchan
# Processing Record 43 of set 14 | vostok
# Processing Record 44 of set 14 | chumikan
# Processing Record 45 of set 14 | miandrivazo
# Processing Record 46 of set 14 | tazovskiy
# Processing Record 47 of set 14 | lulea
# Processing Record 48 of set 14 | yar-sale
# Processing Record 49 of set 14 | pochutla
# Processing Record 50 of set 14 | poli
# Processing Record 1 of set 15 | santa isabel do rio negro
# Processing Record 2 of set 15 | lingao
# Processing Record 3 of set 15 | hasilpur
# Processing Record 4 of set 15 | kuytun
# Processing Record 5 of set 15 | bowen
# Processing Record 6 of set 15 | kaniama
# Processing Record 7 of set 15 | korla
# Processing Record 8 of set 15 | roebourne
# Processing Record 9 of set 15 | champerico
# Processing Record 10 of set 15 | viedma
# Processing Record 11 of set 15 | trincomalee
# Processing Record 12 of set 15 | contramaestre
# Processing Record 13 of set 15 | samarai
# Processing Record 14 of set 15 | koster
# Processing Record 15 of set 15 | kuche
# City not found. Skipping...
# Processing Record 16 of set 15 | bealanana
# Processing Record 17 of set 15 | den helder
# Processing Record 18 of set 15 | laredo
# Processing Record 19 of set 15 | kedougou
# Processing Record 20 of set 15 | sistranda
# Processing Record 21 of set 15 | rio gallegos
# Processing Record 22 of set 15 | kyzyl-suu
# Processing Record 23 of set 15 | canitas
# City not found. Skipping...
# Processing Record 24 of set 15 | livingston
# Processing Record 25 of set 15 | yendi
# Processing Record 26 of set 15 | bafra
# Processing Record 27 of set 15 | nambucca heads
# Processing Record 28 of set 15 | bandarbeyla
# Processing Record 29 of set 15 | san cristobal
# Processing Record 30 of set 15 | russell
# Processing Record 31 of set 15 | kwinana
# Processing Record 32 of set 15 | healdsburg
# Processing Record 33 of set 15 | yuma
# Processing Record 34 of set 15 | nampula
# Processing Record 35 of set 15 | porto novo
# Processing Record 36 of set 15 | chingola
# Processing Record 37 of set 15 | kuching
# Processing Record 38 of set 15 | coromandel
# Processing Record 39 of set 15 | thinadhoo
# Processing Record 40 of set 15 | poya
# Processing Record 41 of set 15 | diamantino
# Processing Record 42 of set 15 | lasa
# Processing Record 43 of set 15 | taihe
# Processing Record 44 of set 15 | fernie
# Processing Record 45 of set 15 | saint-leu
# Processing Record 46 of set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of set 15 | bozdar
# Processing Record 48 of set 15 | esterhazy
# Processing Record 49 of set 15 | gushikawa
# Processing Record 50 of set 15 | liberal
# Processing Record 1 of set 16 | buritis
# Processing Record 2 of set 16 | balkhash
# Processing Record 3 of set 16 | kismayo
# Processing Record 4 of set 16 | koutiala
# Processing Record 5 of set 16 | kohlu
# Processing Record 6 of set 16 | morant bay
# Processing Record 7 of set 16 | linjiang
# Processing Record 8 of set 16 | jatiroto
# Processing Record 9 of set 16 | roald
# Processing Record 10 of set 16 | lhuntshi
# City not found. Skipping...
# Processing Record 11 of set 16 | kabin buri
# Processing Record 12 of set 16 | samagaltay
# Processing Record 13 of set 16 | vestmannaeyjar
# Processing Record 14 of set 16 | mingguang
# Processing Record 15 of set 16 | rio cuarto
# -----------------------------
#    Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 710

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Qaanaaq  77.4840  -69.3632      1.54        71         100
# 1         Coihaique -45.5752  -72.0662     54.21        76           0
# 2         Geraldton -28.7667  114.6000    111.61         7           0
# 3        Bredasdorp -34.5322   20.0403     67.32        64          34
# 4           Barinas   8.6226  -70.2075     78.84        69          81
# 5       Derzhavinsk  51.1000   66.3167     15.93        75         100
# 6          Lorengau  -2.0226  147.2712     84.85        65          98
# 7         Sinnamary   5.3833  -52.9500     75.78        88          85
# 8  Aleksandrovskoye  44.7142   43.0008     28.54        74          99
# 9        Kaitangata -46.2817  169.8464     55.98        58          16
#
#    Wind Speed Country Weather Description
# 0        6.29      GL     overcast clouds
# 1        4.61      CL           clear sky
# 2        5.75      AU           clear sky
# 3       16.11      ZA    scattered clouds
# 4        3.44      VE       broken clouds
# 5       12.97      KZ     overcast clouds
# 6        9.95      PG     overcast clouds
# 7        8.55      GF     overcast clouds
# 8       19.66      RU          light snow
# 9        7.40      NZ          few clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
