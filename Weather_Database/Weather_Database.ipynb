# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 725

# %%
import requests

# Import the API key
from API_config import weather_api_key

# starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# Import the datetime module from the datetime library
import time
from datetime import datetime

type(url)
# Out:
# str

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval          ")
print("------------------------          ")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create the endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d   %H:%M:%S")
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat, 
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Weather Description": weather_description})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate the data loading is complete.
print("-----------------------------")
print("   Data Retrieval Complete   ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of set 1 | karakose
# City not found. Skipping...
# Processing Record 2 of set 1 | rikitea
# Processing Record 3 of set 1 | hermanus
# Processing Record 4 of set 1 | roma
# Processing Record 5 of set 1 | nicoya
# Processing Record 6 of set 1 | severo-kurilsk
# Processing Record 7 of set 1 | malanje
# Processing Record 8 of set 1 | hithadhoo
# Processing Record 9 of set 1 | port alfred
# Processing Record 10 of set 1 | lompoc
# Processing Record 11 of set 1 | saint anthony
# Processing Record 12 of set 1 | ushuaia
# Processing Record 13 of set 1 | jamestown
# Processing Record 14 of set 1 | albany
# Processing Record 15 of set 1 | sol-iletsk
# Processing Record 16 of set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of set 1 | muli
# Processing Record 18 of set 1 | mbanza-ngungu
# Processing Record 19 of set 1 | busselton
# Processing Record 20 of set 1 | saskylakh
# Processing Record 21 of set 1 | codrington
# Processing Record 22 of set 1 | san pedro
# Processing Record 23 of set 1 | bredasdorp
# Processing Record 24 of set 1 | bluff
# Processing Record 25 of set 1 | lagoa
# Processing Record 26 of set 1 | banda aceh
# Processing Record 27 of set 1 | castro
# Processing Record 28 of set 1 | esteio
# Processing Record 29 of set 1 | bethel
# Processing Record 30 of set 1 | saint-gaudens
# Processing Record 31 of set 1 | avarua
# Processing Record 32 of set 1 | georgetown
# Processing Record 33 of set 1 | abu samrah
# Processing Record 34 of set 1 | ewa beach
# Processing Record 35 of set 1 | muzhi
# Processing Record 36 of set 1 | miramar
# Processing Record 37 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of set 1 | grand river south east
# City not found. Skipping...
# Processing Record 40 of set 1 | iberia
# Processing Record 41 of set 1 | ponta do sol
# Processing Record 42 of set 1 | gouyave
# Processing Record 43 of set 1 | ancud
# Processing Record 44 of set 1 | ribeira grande
# Processing Record 45 of set 1 | isangel
# Processing Record 46 of set 1 | tuktoyaktuk
# Processing Record 47 of set 1 | kapaa
# Processing Record 48 of set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of set 1 | sechura
# Processing Record 50 of set 1 | port elizabeth
# Processing Record 1 of set 2 | port said
# Processing Record 2 of set 2 | lalomanu
# City not found. Skipping...
# Processing Record 3 of set 2 | sakakah
# Processing Record 4 of set 2 | butaritari
# Processing Record 5 of set 2 | kaeo
# Processing Record 6 of set 2 | duluth
# Processing Record 7 of set 2 | punta arenas
# Processing Record 8 of set 2 | yellowknife
# Processing Record 9 of set 2 | holbeach
# Processing Record 10 of set 2 | narsaq
# Processing Record 11 of set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of set 2 | provideniya
# Processing Record 13 of set 2 | pontianak
# Processing Record 14 of set 2 | vaitupu
# City not found. Skipping...
# Processing Record 15 of set 2 | kailua
# Processing Record 16 of set 2 | airai
# Processing Record 17 of set 2 | puerto ayora
# Processing Record 18 of set 2 | san quintin
# Processing Record 19 of set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of set 2 | tasiilaq
# Processing Record 21 of set 2 | torbay
# Processing Record 22 of set 2 | hofn
# Processing Record 23 of set 2 | padang
# Processing Record 24 of set 2 | caravelas
# Processing Record 25 of set 2 | atuona
# Processing Record 26 of set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of set 2 | chokurdakh
# Processing Record 28 of set 2 | cravo norte
# Processing Record 29 of set 2 | salalah
# Processing Record 30 of set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of set 2 | carnarvon
# Processing Record 32 of set 2 | aklavik
# Processing Record 33 of set 2 | praia da vitoria
# Processing Record 34 of set 2 | tual
# Processing Record 35 of set 2 | upernavik
# Processing Record 36 of set 2 | vaini
# Processing Record 37 of set 2 | umm lajj
# Processing Record 38 of set 2 | bathsheba
# Processing Record 39 of set 2 | new norfolk
# Processing Record 40 of set 2 | san policarpo
# Processing Record 41 of set 2 | tuatapere
# Processing Record 42 of set 2 | gumdag
# Processing Record 43 of set 2 | kodiak
# Processing Record 44 of set 2 | maldonado
# Processing Record 45 of set 2 | cherskiy
# Processing Record 46 of set 2 | burns lake
# Processing Record 47 of set 2 | lebanon
# Processing Record 48 of set 2 | mehamn
# Processing Record 49 of set 2 | mataura
# Processing Record 50 of set 2 | nizwa
# Processing Record 1 of set 3 | khao wong
# Processing Record 2 of set 3 | rundu
# Processing Record 3 of set 3 | ketchikan
# Processing Record 4 of set 3 | neuenhagen
# Processing Record 5 of set 3 | okakarara
# Processing Record 6 of set 3 | barrow
# Processing Record 7 of set 3 | atasu
# Processing Record 8 of set 3 | west wendover
# Processing Record 9 of set 3 | longyearbyen
# Processing Record 10 of set 3 | colac
# Processing Record 11 of set 3 | hosangadi
# Processing Record 12 of set 3 | laguna
# Processing Record 13 of set 3 | mount isa
# Processing Record 14 of set 3 | nikolskoye
# Processing Record 15 of set 3 | clyde river
# Processing Record 16 of set 3 | arraial do cabo
# Processing Record 17 of set 3 | port blair
# Processing Record 18 of set 3 | east london
# Processing Record 19 of set 3 | mar del plata
# Processing Record 20 of set 3 | cape town
# Processing Record 21 of set 3 | pitimbu
# Processing Record 22 of set 3 | qaanaaq
# Processing Record 23 of set 3 | sonamura
# Processing Record 24 of set 3 | umm kaddadah
# Processing Record 25 of set 3 | west bay
# Processing Record 26 of set 3 | evensk
# Processing Record 27 of set 3 | garoua
# Processing Record 28 of set 3 | norman wells
# Processing Record 29 of set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of set 3 | gangotri
# City not found. Skipping...
# Processing Record 31 of set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of set 3 | esperance
# Processing Record 33 of set 3 | san carlos de bariloche
# Processing Record 34 of set 3 | sinjah
# City not found. Skipping...
# Processing Record 35 of set 3 | yining
# Processing Record 36 of set 3 | yerbogachen
# Processing Record 37 of set 3 | hasaki
# Processing Record 38 of set 3 | cidreira
# Processing Record 39 of set 3 | jambi
# Processing Record 40 of set 3 | berlevag
# Processing Record 41 of set 3 | iqaluit
# Processing Record 42 of set 3 | aasiaat
# Processing Record 43 of set 3 | beringovskiy
# Processing Record 44 of set 3 | ilulissat
# Processing Record 45 of set 3 | poitiers
# Processing Record 46 of set 3 | saint-philippe
# Processing Record 47 of set 3 | cibitoke
# Processing Record 48 of set 3 | grindavik
# Processing Record 49 of set 3 | villazon
# Processing Record 50 of set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of set 4 | nampula
# Processing Record 2 of set 4 | port macquarie
# Processing Record 3 of set 4 | san lazaro
# Processing Record 4 of set 4 | parras
# City not found. Skipping...
# Processing Record 5 of set 4 | viedma
# Processing Record 6 of set 4 | ambovombe
# Processing Record 7 of set 4 | coahuayana
# Processing Record 8 of set 4 | cabo san lucas
# Processing Record 9 of set 4 | victoria point
# Processing Record 10 of set 4 | alugan
# Processing Record 11 of set 4 | siraha
# Processing Record 12 of set 4 | bougouni
# Processing Record 13 of set 4 | fengrun
# Processing Record 14 of set 4 | navoi
# Processing Record 15 of set 4 | oytal
# Processing Record 16 of set 4 | turangi
# Processing Record 17 of set 4 | pemangkat
# Processing Record 18 of set 4 | dhilwan
# Processing Record 19 of set 4 | gambela
# Processing Record 20 of set 4 | lorengau
# Processing Record 21 of set 4 | chicama
# Processing Record 22 of set 4 | victoria
# Processing Record 23 of set 4 | sola
# Processing Record 24 of set 4 | fort nelson
# Processing Record 25 of set 4 | vardo
# Processing Record 26 of set 4 | naze
# Processing Record 27 of set 4 | alofi
# Processing Record 28 of set 4 | hobart
# Processing Record 29 of set 4 | hunza
# City not found. Skipping...
# Processing Record 30 of set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of set 4 | dwarka
# Processing Record 32 of set 4 | christchurch
# Processing Record 33 of set 4 | rocha
# Processing Record 34 of set 4 | half moon bay
# Processing Record 35 of set 4 | saldanha
# Processing Record 36 of set 4 | kruisfontein
# Processing Record 37 of set 4 | tabiauea
# City not found. Skipping...
# Processing Record 38 of set 4 | boende
# Processing Record 39 of set 4 | taoudenni
# Processing Record 40 of set 4 | yantal
# Processing Record 41 of set 4 | kahului
# Processing Record 42 of set 4 | tiksi
# Processing Record 43 of set 4 | hervey bay
# Processing Record 44 of set 4 | pevek
# Processing Record 45 of set 4 | palmer
# Processing Record 46 of set 4 | novokayakent
# Processing Record 47 of set 4 | faanui
# Processing Record 48 of set 4 | erzin
# Processing Record 49 of set 4 | sao filipe
# Processing Record 50 of set 4 | los llanos de aridane
# Processing Record 1 of set 5 | santa marta
# Processing Record 2 of set 5 | arica
# Processing Record 3 of set 5 | sevlievo
# Processing Record 4 of set 5 | banikoara
# Processing Record 5 of set 5 | olafsvik
# Processing Record 6 of set 5 | palo alto
# Processing Record 7 of set 5 | beloha
# Processing Record 8 of set 5 | prince rupert
# Processing Record 9 of set 5 | bilibino
# Processing Record 10 of set 5 | tombouctou
# Processing Record 11 of set 5 | ciudad bolivar
# Processing Record 12 of set 5 | urucara
# Processing Record 13 of set 5 | koslan
# Processing Record 14 of set 5 | columbus
# Processing Record 15 of set 5 | kalmunai
# Processing Record 16 of set 5 | saint george
# Processing Record 17 of set 5 | south venice
# Processing Record 18 of set 5 | minot
# Processing Record 19 of set 5 | cozumel
# Processing Record 20 of set 5 | calvinia
# Processing Record 21 of set 5 | zhigansk
# Processing Record 22 of set 5 | vila velha
# Processing Record 23 of set 5 | chino valley
# Processing Record 24 of set 5 | pietarsaari
# Processing Record 25 of set 5 | awbari
# Processing Record 26 of set 5 | miri
# Processing Record 27 of set 5 | batticaloa
# Processing Record 28 of set 5 | belyy yar
# Processing Record 29 of set 5 | vestmannaeyjar
# Processing Record 30 of set 5 | dikson
# Processing Record 31 of set 5 | hualmay
# Processing Record 32 of set 5 | pribelskiy
# City not found. Skipping...
# Processing Record 33 of set 5 | kristiansund
# Processing Record 34 of set 5 | salinas
# Processing Record 35 of set 5 | tikapur
# Processing Record 36 of set 5 | kisangani
# Processing Record 37 of set 5 | pochutla
# Processing Record 38 of set 5 | kupino
# Processing Record 39 of set 5 | sayyan
# Processing Record 40 of set 5 | am timan
# Processing Record 41 of set 5 | namibe
# Processing Record 42 of set 5 | sabang
# Processing Record 43 of set 5 | lima
# Processing Record 44 of set 5 | thompson
# Processing Record 45 of set 5 | wahran
# City not found. Skipping...
# Processing Record 46 of set 5 | henzada
# City not found. Skipping...
# Processing Record 47 of set 5 | havelock
# Processing Record 48 of set 5 | mahebourg
# Processing Record 49 of set 5 | bengkulu
# Processing Record 50 of set 5 | hilo
# Processing Record 1 of set 6 | araouane
# Processing Record 2 of set 6 | saint-joseph
# Processing Record 3 of set 6 | klaksvik
# Processing Record 4 of set 6 | lianyuan
# Processing Record 5 of set 6 | linfen
# Processing Record 6 of set 6 | storforshei
# Processing Record 7 of set 6 | degtyarsk
# Processing Record 8 of set 6 | ahipara
# Processing Record 9 of set 6 | cayenne
# Processing Record 10 of set 6 | nome
# Processing Record 11 of set 6 | pisco
# Processing Record 12 of set 6 | zvishavane
# Processing Record 13 of set 6 | flin flon
# Processing Record 14 of set 6 | ginir
# Processing Record 15 of set 6 | yar-sale
# Processing Record 16 of set 6 | lebu
# Processing Record 17 of set 6 | constitucion
# Processing Record 18 of set 6 | khatanga
# Processing Record 19 of set 6 | qaqortoq
# Processing Record 20 of set 6 | wukari
# Processing Record 21 of set 6 | opuwo
# Processing Record 22 of set 6 | huilong
# Processing Record 23 of set 6 | kalat
# Processing Record 24 of set 6 | kununurra
# Processing Record 25 of set 6 | kaya
# Processing Record 26 of set 6 | skibbereen
# Processing Record 27 of set 6 | vao
# Processing Record 28 of set 6 | vila franca do campo
# Processing Record 29 of set 6 | krasnoslobodsk
# Processing Record 30 of set 6 | iwanai
# Processing Record 31 of set 6 | mantua
# Processing Record 32 of set 6 | chuy
# Processing Record 33 of set 6 | dakar
# Processing Record 34 of set 6 | katra
# Processing Record 35 of set 6 | warqla
# City not found. Skipping...
# Processing Record 36 of set 6 | saleaula
# City not found. Skipping...
# Processing Record 37 of set 6 | amga
# Processing Record 38 of set 6 | coquimbo
# Processing Record 39 of set 6 | jos
# Processing Record 40 of set 6 | tamworth
# Processing Record 41 of set 6 | coolum beach
# Processing Record 42 of set 6 | auki
# Processing Record 43 of set 6 | maningrida
# Processing Record 44 of set 6 | pahrump
# Processing Record 45 of set 6 | entre rios
# Processing Record 46 of set 6 | atherton
# Processing Record 47 of set 6 | kawalu
# Processing Record 48 of set 6 | naryan-mar
# Processing Record 49 of set 6 | datong
# Processing Record 50 of set 6 | tsihombe
# City not found. Skipping...
# Processing Record 1 of set 7 | jumla
# Processing Record 2 of set 7 | delmas
# Processing Record 3 of set 7 | meulaboh
# Processing Record 4 of set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of set 7 | tuku
# Processing Record 6 of set 7 | rawson
# Processing Record 7 of set 7 | tromso
# Processing Record 8 of set 7 | thinadhoo
# Processing Record 9 of set 7 | peniche
# Processing Record 10 of set 7 | quevedo
# Processing Record 11 of set 7 | alice springs
# Processing Record 12 of set 7 | ratnagiri
# Processing Record 13 of set 7 | pasighat
# Processing Record 14 of set 7 | saint-pierre
# Processing Record 15 of set 7 | guerrero negro
# Processing Record 16 of set 7 | karratha
# Processing Record 17 of set 7 | lipin bor
# Processing Record 18 of set 7 | katsuura
# Processing Record 19 of set 7 | meyungs
# City not found. Skipping...
# Processing Record 20 of set 7 | nautla
# Processing Record 21 of set 7 | oistins
# Processing Record 22 of set 7 | zirandaro
# Processing Record 23 of set 7 | dingle
# Processing Record 24 of set 7 | college
# Processing Record 25 of set 7 | tungkang
# City not found. Skipping...
# Processing Record 26 of set 7 | voyskovitsy
# Processing Record 27 of set 7 | severo-yeniseyskiy
# Processing Record 28 of set 7 | puntarenas
# Processing Record 29 of set 7 | hoi an
# Processing Record 30 of set 7 | gladstone
# Processing Record 31 of set 7 | labuhan
# Processing Record 32 of set 7 | paonta sahib
# Processing Record 33 of set 7 | moree
# Processing Record 34 of set 7 | san jeronimo
# Processing Record 35 of set 7 | lasa
# Processing Record 36 of set 7 | balimo
# City not found. Skipping...
# Processing Record 37 of set 7 | lata
# Processing Record 38 of set 7 | helong
# Processing Record 39 of set 7 | piranshahr
# Processing Record 40 of set 7 | beipiao
# Processing Record 41 of set 7 | kawana waters
# City not found. Skipping...
# Processing Record 42 of set 7 | samusu
# City not found. Skipping...
# Processing Record 43 of set 7 | sitka
# Processing Record 44 of set 7 | acapulco
# Processing Record 45 of set 7 | lavrentiya
# Processing Record 46 of set 7 | tres lagoas
# Processing Record 47 of set 7 | dudinka
# Processing Record 48 of set 7 | chom bung
# City not found. Skipping...
# Processing Record 49 of set 7 | chala
# Processing Record 50 of set 7 | jinchang
# Processing Record 1 of set 8 | manjakandriana
# Processing Record 2 of set 8 | bonnyville
# Processing Record 3 of set 8 | portland
# Processing Record 4 of set 8 | jalu
# Processing Record 5 of set 8 | macaboboni
# City not found. Skipping...
# Processing Record 6 of set 8 | itaituba
# Processing Record 7 of set 8 | grand gaube
# Processing Record 8 of set 8 | oktyabrskoye
# Processing Record 9 of set 8 | kaitangata
# Processing Record 10 of set 8 | gondanglegi
# Processing Record 11 of set 8 | jacareacanga
# Processing Record 12 of set 8 | valparaiso
# Processing Record 13 of set 8 | burewala
# Processing Record 14 of set 8 | ladario
# Processing Record 15 of set 8 | kuching
# Processing Record 16 of set 8 | kalga
# Processing Record 17 of set 8 | pangnirtung
# Processing Record 18 of set 8 | holme
# Processing Record 19 of set 8 | anadyr
# Processing Record 20 of set 8 | merzifon
# Processing Record 21 of set 8 | matagami
# Processing Record 22 of set 8 | san patricio
# Processing Record 23 of set 8 | barbar
# City not found. Skipping...
# Processing Record 24 of set 8 | broome
# Processing Record 25 of set 8 | auray
# Processing Record 26 of set 8 | ostrovnoy
# Processing Record 27 of set 8 | guane
# Processing Record 28 of set 8 | diu
# Processing Record 29 of set 8 | mugango
# Processing Record 30 of set 8 | mana
# Processing Record 31 of set 8 | balsthal
# Processing Record 32 of set 8 | alibag
# Processing Record 33 of set 8 | nyanguge
# Processing Record 34 of set 8 | mingaora
# Processing Record 35 of set 8 | cabedelo
# Processing Record 36 of set 8 | buala
# Processing Record 37 of set 8 | yukon
# Processing Record 38 of set 8 | makakilo city
# Processing Record 39 of set 8 | teguldet
# Processing Record 40 of set 8 | bambous virieux
# Processing Record 41 of set 8 | tucurui
# Processing Record 42 of set 8 | port lincoln
# Processing Record 43 of set 8 | kilindoni
# Processing Record 44 of set 8 | ilovlya
# Processing Record 45 of set 8 | bubanza
# Processing Record 46 of set 8 | kirakira
# Processing Record 47 of set 8 | caucaia
# Processing Record 48 of set 8 | toliary
# City not found. Skipping...
# Processing Record 49 of set 8 | sturgeon bay
# Processing Record 50 of set 8 | hokitika
# Processing Record 1 of set 9 | panjwin
# City not found. Skipping...
# Processing Record 2 of set 9 | gat
# Processing Record 3 of set 9 | bouna
# Processing Record 4 of set 9 | necochea
# Processing Record 5 of set 9 | hamilton
# Processing Record 6 of set 9 | kharagauli
# Processing Record 7 of set 9 | kenai
# Processing Record 8 of set 9 | san cristobal
# Processing Record 9 of set 9 | santa isabel do rio negro
# Processing Record 10 of set 9 | innisfail
# Processing Record 11 of set 9 | larsnes
# Processing Record 12 of set 9 | cumra
# Processing Record 13 of set 9 | zelenets
# Processing Record 14 of set 9 | palasa
# Processing Record 15 of set 9 | balkanabat
# Processing Record 16 of set 9 | takaka
# Processing Record 17 of set 9 | asau
# Processing Record 18 of set 9 | falam
# Processing Record 19 of set 9 | benjamin constant
# Processing Record 20 of set 9 | karaul
# City not found. Skipping...
# Processing Record 21 of set 9 | diamantino
# Processing Record 22 of set 9 | khandbari
# Processing Record 23 of set 9 | cururupu
# Processing Record 24 of set 9 | matara
# Processing Record 25 of set 9 | batagay-alyta
# Processing Record 26 of set 9 | sinnamary
# Processing Record 27 of set 9 | fairbanks
# Processing Record 28 of set 9 | porto novo
# Processing Record 29 of set 9 | kavieng
# Processing Record 30 of set 9 | fortuna
# Processing Record 31 of set 9 | jaguaruna
# Processing Record 32 of set 9 | whitefish
# Processing Record 33 of set 9 | ajdabiya
# Processing Record 34 of set 9 | shimoda
# Processing Record 35 of set 9 | petropavlovka
# Processing Record 36 of set 9 | linxia
# Processing Record 37 of set 9 | tazovskiy
# Processing Record 38 of set 9 | san matias
# Processing Record 39 of set 9 | ous
# Processing Record 40 of set 9 | quelimane
# Processing Record 41 of set 9 | puerto ayacucho
# Processing Record 42 of set 9 | slave lake
# Processing Record 43 of set 9 | shelburne
# Processing Record 44 of set 9 | ballina
# Processing Record 45 of set 9 | omboue
# Processing Record 46 of set 9 | tautira
# Processing Record 47 of set 9 | illapel
# Processing Record 48 of set 9 | kasane
# Processing Record 49 of set 9 | sandy bay
# Processing Record 50 of set 9 | suntar
# Processing Record 1 of set 10 | termoli
# Processing Record 2 of set 10 | rio gallegos
# Processing Record 3 of set 10 | bargal
# City not found. Skipping...
# Processing Record 4 of set 10 | fuerte olimpo
# Processing Record 5 of set 10 | san vicente
# Processing Record 6 of set 10 | maumere
# Processing Record 7 of set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 8 of set 10 | tongzi
# Processing Record 9 of set 10 | nemuro
# Processing Record 10 of set 10 | saint-augustin
# Processing Record 11 of set 10 | togur
# Processing Record 12 of set 10 | kuusamo
# Processing Record 13 of set 10 | husavik
# Processing Record 14 of set 10 | muroto
# Processing Record 15 of set 10 | vrangel
# Processing Record 16 of set 10 | biak
# Processing Record 17 of set 10 | dunedin
# Processing Record 18 of set 10 | shuya
# Processing Record 19 of set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of set 10 | yuksekova
# Processing Record 21 of set 10 | cumaribo
# City not found. Skipping...
# Processing Record 22 of set 10 | darnah
# Processing Record 23 of set 10 | oranjemund
# Processing Record 24 of set 10 | coreau
# Processing Record 25 of set 10 | kiunga
# Processing Record 26 of set 10 | souillac
# Processing Record 27 of set 10 | bubaque
# Processing Record 28 of set 10 | camacha
# Processing Record 29 of set 10 | shache
# Processing Record 30 of set 10 | nyaunglebin
# Processing Record 31 of set 10 | ustyuzhna
# Processing Record 32 of set 10 | karpathos
# Processing Record 33 of set 10 | mizdah
# Processing Record 34 of set 10 | wanaka
# Processing Record 35 of set 10 | bella union
# Processing Record 36 of set 10 | dosso
# Processing Record 37 of set 10 | yulara
# Processing Record 38 of set 10 | saint-louis
# Processing Record 39 of set 10 | kiama
# Processing Record 40 of set 10 | ossora
# Processing Record 41 of set 10 | leshukonskoye
# Processing Record 42 of set 10 | lusambo
# Processing Record 43 of set 10 | zaoyang
# Processing Record 44 of set 10 | svetlaya
# Processing Record 45 of set 10 | cockburn town
# Processing Record 46 of set 10 | qui nhon
# Processing Record 47 of set 10 | bagnols-sur-ceze
# Processing Record 48 of set 10 | marawi
# Processing Record 49 of set 10 | samarai
# Processing Record 50 of set 10 | komsomolskiy
# Processing Record 1 of set 11 | suez
# Processing Record 2 of set 11 | wanning
# Processing Record 3 of set 11 | ucluelet
# Processing Record 4 of set 11 | gualeguaychu
# Processing Record 5 of set 11 | geraldton
# Processing Record 6 of set 11 | hambantota
# Processing Record 7 of set 11 | zhezkazgan
# Processing Record 8 of set 11 | mawlaik
# Processing Record 9 of set 11 | cajabamba
# Processing Record 10 of set 11 | luanda
# Processing Record 11 of set 11 | singaraja
# Processing Record 12 of set 11 | kakogawa
# Processing Record 13 of set 11 | mahibadhoo
# Processing Record 14 of set 11 | telimele
# Processing Record 15 of set 11 | kanigiri
# Processing Record 16 of set 11 | ende
# Processing Record 17 of set 11 | the valley
# Processing Record 18 of set 11 | goedereede
# Processing Record 19 of set 11 | sindi
# Processing Record 20 of set 11 | ghanzi
# Processing Record 21 of set 11 | yarovoye
# Processing Record 22 of set 11 | deputatskiy
# Processing Record 23 of set 11 | ardmore
# Processing Record 24 of set 11 | pangody
# Processing Record 25 of set 11 | northam
# Processing Record 26 of set 11 | shunyi
# Processing Record 27 of set 11 | dongsheng
# Processing Record 28 of set 11 | selkirk
# Processing Record 29 of set 11 | turkan
# Processing Record 30 of set 11 | kapuskasing
# Processing Record 31 of set 11 | corrente
# Processing Record 32 of set 11 | abha
# Processing Record 33 of set 11 | tilichiki
# Processing Record 34 of set 11 | tres arroyos
# Processing Record 35 of set 11 | altagracia de orituco
# Processing Record 36 of set 11 | richards bay
# Processing Record 37 of set 11 | zhangjiakou
# Processing Record 38 of set 11 | liberec
# Processing Record 39 of set 11 | la sarre
# Processing Record 40 of set 11 | coria
# Processing Record 41 of set 11 | north bend
# Processing Record 42 of set 11 | plettenberg bay
# Processing Record 43 of set 11 | ponta delgada
# Processing Record 44 of set 11 | polovinnoye
# Processing Record 45 of set 11 | vila
# Processing Record 46 of set 11 | mutis
# Processing Record 47 of set 11 | mount gambier
# Processing Record 48 of set 11 | gornyy
# Processing Record 49 of set 11 | diapaga
# Processing Record 50 of set 11 | nogliki
# Processing Record 1 of set 12 | seoul
# Processing Record 2 of set 12 | kabalo
# Processing Record 3 of set 12 | santiago
# Processing Record 4 of set 12 | olinda
# Processing Record 5 of set 12 | aguimes
# Processing Record 6 of set 12 | petropavlovsk-kamchatskiy
# Processing Record 7 of set 12 | baijiantan
# Processing Record 8 of set 12 | havoysund
# Processing Record 9 of set 12 | mercedes
# Processing Record 10 of set 12 | vanimo
# Processing Record 11 of set 12 | kingisepp
# Processing Record 12 of set 12 | pingliang
# Processing Record 13 of set 12 | cherdakly
# Processing Record 14 of set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 15 of set 12 | lazaro cardenas
# Processing Record 16 of set 12 | tuban
# Processing Record 17 of set 12 | leningradskiy
# Processing Record 18 of set 12 | mogadishu
# Processing Record 19 of set 12 | luleburgaz
# Processing Record 20 of set 12 | luangwa
# Processing Record 21 of set 12 | eirunepe
# Processing Record 22 of set 12 | galesong
# Processing Record 23 of set 12 | mocambique
# City not found. Skipping...
# Processing Record 24 of set 12 | phuket
# Processing Record 25 of set 12 | jining
# Processing Record 26 of set 12 | san pedro de macoris
# Processing Record 27 of set 12 | rokytne
# Processing Record 28 of set 12 | kieta
# Processing Record 29 of set 12 | mrirt
# City not found. Skipping...
# Processing Record 30 of set 12 | port augusta
# Processing Record 31 of set 12 | san ramon
# Processing Record 32 of set 12 | kidal
# Processing Record 33 of set 12 | muros
# Processing Record 34 of set 12 | mombetsu
# Processing Record 35 of set 12 | casimiro de abreu
# Processing Record 36 of set 12 | machico
# Processing Record 37 of set 12 | amahai
# Processing Record 38 of set 12 | monroe
# Processing Record 39 of set 12 | ovsyanka
# Processing Record 40 of set 12 | mbacke
# City not found. Skipping...
# Processing Record 41 of set 12 | yomitan
# City not found. Skipping...
# Processing Record 42 of set 12 | nyakahanga
# Processing Record 43 of set 12 | oksfjord
# Processing Record 44 of set 12 | naantali
# Processing Record 45 of set 12 | sete lagoas
# Processing Record 46 of set 12 | enshi
# Processing Record 47 of set 12 | nanortalik
# Processing Record 48 of set 12 | puli
# Processing Record 49 of set 12 | gorontalo
# Processing Record 50 of set 12 | ati
# Processing Record 1 of set 13 | shirokiy
# Processing Record 2 of set 13 | madimba
# Processing Record 3 of set 13 | fujin
# Processing Record 4 of set 13 | prieska
# Processing Record 5 of set 13 | harper
# Processing Record 6 of set 13 | ust-omchug
# Processing Record 7 of set 13 | agadez
# Processing Record 8 of set 13 | kindu
# Processing Record 9 of set 13 | srednekolymsk
# Processing Record 10 of set 13 | salisbury
# Processing Record 11 of set 13 | flinders
# Processing Record 12 of set 13 | hami
# Processing Record 13 of set 13 | belaya gora
# Processing Record 14 of set 13 | lagos
# Processing Record 15 of set 13 | glyadyanskoye
# Processing Record 16 of set 13 | yetholm
# City not found. Skipping...
# Processing Record 17 of set 13 | ambilobe
# Processing Record 18 of set 13 | yilan
# Processing Record 19 of set 13 | eureka
# Processing Record 20 of set 13 | adrar
# Processing Record 21 of set 13 | kabanjahe
# Processing Record 22 of set 13 | novyy urengoy
# Processing Record 23 of set 13 | sringeri
# Processing Record 24 of set 13 | arawa
# Processing Record 25 of set 13 | nishihara
# Processing Record 26 of set 13 | pimenta bueno
# Processing Record 27 of set 13 | kagadi
# Processing Record 28 of set 13 | chkalovskoye
# Processing Record 29 of set 13 | pyapon
# Processing Record 30 of set 13 | uzunovo
# Processing Record 31 of set 13 | malinovoye ozero
# Processing Record 32 of set 13 | almenara
# Processing Record 33 of set 13 | verkhnevilyuysk
# Processing Record 34 of set 13 | kitgum
# Processing Record 35 of set 13 | okhotsk
# Processing Record 36 of set 13 | carlyle
# Processing Record 37 of set 13 | kudahuvadhoo
# Processing Record 38 of set 13 | artyk
# City not found. Skipping...
# Processing Record 39 of set 13 | stornoway
# Processing Record 40 of set 13 | waterloo
# Processing Record 41 of set 13 | ivanteyevka
# Processing Record 42 of set 13 | raduzhnyy
# Processing Record 43 of set 13 | gigmoto
# Processing Record 44 of set 13 | nisia floresta
# Processing Record 45 of set 13 | lakselv
# Processing Record 46 of set 13 | leh
# Processing Record 47 of set 13 | ulaangom
# Processing Record 48 of set 13 | waingapu
# Processing Record 49 of set 13 | felidhoo
# City not found. Skipping...
# Processing Record 50 of set 13 | tukrah
# Processing Record 1 of set 14 | champerico
# Processing Record 2 of set 14 | straumen
# Processing Record 3 of set 14 | narok
# Processing Record 4 of set 14 | filingue
# Processing Record 5 of set 14 | itarema
# Processing Record 6 of set 14 | purgstall
# Processing Record 7 of set 14 | cookeville
# Processing Record 8 of set 14 | touros
# Processing Record 9 of set 14 | nouadhibou
# Processing Record 10 of set 14 | patti
# Processing Record 11 of set 14 | thunder bay
# Processing Record 12 of set 14 | vostok
# Processing Record 13 of set 14 | kuche
# City not found. Skipping...
# Processing Record 14 of set 14 | haines junction
# Processing Record 15 of set 14 | rosario oeste
# Processing Record 16 of set 14 | tayga
# Processing Record 17 of set 14 | bukachacha
# Processing Record 18 of set 14 | omsukchan
# Processing Record 19 of set 14 | jijiga
# Processing Record 20 of set 14 | redhakhol
# City not found. Skipping...
# Processing Record 21 of set 14 | palm coast
# Processing Record 22 of set 14 | wangqing
# Processing Record 23 of set 14 | kyzyl-suu
# Processing Record 24 of set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 25 of set 14 | lubango
# Processing Record 26 of set 14 | ijui
# Processing Record 27 of set 14 | katete
# Processing Record 28 of set 14 | mayo
# Processing Record 29 of set 14 | sibay
# Processing Record 30 of set 14 | sandila
# Processing Record 31 of set 14 | kirksville
# Processing Record 32 of set 14 | westport
# Processing Record 33 of set 14 | noshiro
# Processing Record 34 of set 14 | el ocotito
# Processing Record 35 of set 14 | rio grande
# Processing Record 36 of set 14 | coihaique
# Processing Record 37 of set 14 | quatre cocos
# Processing Record 38 of set 14 | utiroa
# City not found. Skipping...
# Processing Record 39 of set 14 | ushtobe
# Processing Record 40 of set 14 | lisakovsk
# Processing Record 41 of set 14 | louisbourg
# City not found. Skipping...
# Processing Record 42 of set 14 | vanavara
# Processing Record 43 of set 14 | bluefield
# Processing Record 44 of set 14 | ebeltoft
# Processing Record 45 of set 14 | bilma
# Processing Record 46 of set 14 | aykhal
# Processing Record 47 of set 14 | saryshagan
# City not found. Skipping...
# Processing Record 48 of set 14 | nantucket
# Processing Record 49 of set 14 | samoded
# Processing Record 50 of set 14 | bacolod
# Processing Record 1 of set 15 | potosi
# Processing Record 2 of set 15 | akureyri
# Processing Record 3 of set 15 | rungata
# City not found. Skipping...
# Processing Record 4 of set 15 | luderitz
# Processing Record 5 of set 15 | nioro
# Processing Record 6 of set 15 | ilo
# Processing Record 7 of set 15 | galiwinku
# City not found. Skipping...
# Processing Record 8 of set 15 | salinopolis
# Processing Record 9 of set 15 | gimli
# Processing Record 10 of set 15 | awjilah
# Processing Record 11 of set 15 | vostochnyy
# Processing Record 12 of set 15 | yaan
# Processing Record 13 of set 15 | sao joao da barra
# Processing Record 14 of set 15 | hay river
# Processing Record 15 of set 15 | poya
# Processing Record 16 of set 15 | nhulunbuy
# Processing Record 17 of set 15 | damietta
# Processing Record 18 of set 15 | roswell
# Processing Record 19 of set 15 | bitam
# Processing Record 20 of set 15 | mayuge
# Processing Record 21 of set 15 | avera
# Processing Record 22 of set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of set 15 | baherden
# Processing Record 24 of set 15 | wamba
# Processing Record 25 of set 15 | nanyamba
# -----------------------------
#    Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 665

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     78.22        74         100
# 1        Hermanus -34.4187   19.2345     60.91        72          93
# 2            Roma  43.2128  -75.4557     28.96        92         100
# 3          Nicoya  10.1483  -85.4520     74.75        74           3
# 4  Severo-Kurilsk  50.6789  156.1250     30.94        88         100
# 5         Malanje  -9.5402   16.3410     61.54        97         100
# 6       Hithadhoo  -0.6000   73.0833     81.73        74         100
# 7     Port Alfred -33.5906   26.8910     69.84        75          98
# 8          Lompoc  34.6391 -120.4579     53.92        81           0
# 9   Saint Anthony  45.0205  -93.2180      1.02        66           0
#
#    Wind Speed Weather Description
# 0       17.02          light rain
# 1        9.89     overcast clouds
# 2        4.61                 fog
# 3        2.51           clear sky
# 4       10.27          light snow
# 5        1.36          light rain
# 6       10.11     overcast clouds
# 7       15.48     overcast clouds
# 8        0.00                mist
# 9        4.61           clear sky

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
