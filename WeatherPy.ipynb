# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 1500

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %%
import requests
requests.__version__
# Out:
# '2.27.1'

# %%
# Import the API key
from config import weather_api_key

# starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# Import the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval          ")
print("------------------------          ")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create the endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d   %H:%M:%S")
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat, 
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate the data loading is complete.
print("-----------------------------")
print("   Data Retrieval Complete   ")
print("-----------------------------")
# Out:
# Processing Record 1 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of set 1 | atuona
# Processing Record 3 of set 1 | barawe
# City not found. Skipping...
# Processing Record 4 of set 1 | ushuaia
# Processing Record 5 of set 1 | santa maria
# Processing Record 6 of set 1 | kavieng
# Processing Record 7 of set 1 | puerto ayora
# Processing Record 8 of set 1 | khatanga
# Processing Record 9 of set 1 | suez
# Processing Record 10 of set 1 | barrow
# Processing Record 11 of set 1 | rikitea
# Processing Record 12 of set 1 | san patricio
# Processing Record 13 of set 1 | new norfolk
# Processing Record 14 of set 1 | hargeysa
# Processing Record 15 of set 1 | busselton
# Processing Record 16 of set 1 | manta
# Processing Record 17 of set 1 | tuggurt
# City not found. Skipping...
# Processing Record 18 of set 1 | katsuura
# Processing Record 19 of set 1 | albany
# Processing Record 20 of set 1 | bluff
# Processing Record 21 of set 1 | saldanha
# Processing Record 22 of set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of set 1 | taoudenni
# Processing Record 24 of set 1 | deputatskiy
# Processing Record 25 of set 1 | prainha
# Processing Record 26 of set 1 | hilo
# Processing Record 27 of set 1 | garden city
# Processing Record 28 of set 1 | bathsheba
# Processing Record 29 of set 1 | verkhnyaya inta
# Processing Record 30 of set 1 | vanimo
# Processing Record 31 of set 1 | hermanus
# Processing Record 32 of set 1 | cabo san lucas
# Processing Record 33 of set 1 | krionerion
# City not found. Skipping...
# Processing Record 34 of set 1 | mar del plata
# Processing Record 35 of set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of set 1 | aransas pass
# Processing Record 37 of set 1 | avarua
# Processing Record 38 of set 1 | lompoc
# Processing Record 39 of set 1 | georgetown
# Processing Record 40 of set 1 | mataura
# Processing Record 41 of set 1 | port alfred
# Processing Record 42 of set 1 | puri
# Processing Record 43 of set 1 | kawalu
# Processing Record 44 of set 1 | qaanaaq
# Processing Record 45 of set 1 | kawambwa
# Processing Record 46 of set 1 | carnarvon
# Processing Record 47 of set 1 | aitape
# Processing Record 48 of set 1 | cape town
# Processing Record 49 of set 1 | bafra
# Processing Record 50 of set 1 | hasaki
# Processing Record 1 of set 2 | fortuna
# Processing Record 2 of set 2 | samusu
# City not found. Skipping...
# Processing Record 3 of set 2 | abu samrah
# Processing Record 4 of set 2 | east london
# Processing Record 5 of set 2 | kiruna
# Processing Record 6 of set 2 | lake havasu city
# Processing Record 7 of set 2 | kapaa
# Processing Record 8 of set 2 | lebu
# Processing Record 9 of set 2 | yellowknife
# Processing Record 10 of set 2 | baruun-urt
# Processing Record 11 of set 2 | saint-philippe
# Processing Record 12 of set 2 | necochea
# Processing Record 13 of set 2 | biak
# Processing Record 14 of set 2 | mitsamiouli
# Processing Record 15 of set 2 | vaini
# Processing Record 16 of set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of set 2 | darhan
# Processing Record 18 of set 2 | rudbar
# Processing Record 19 of set 2 | portland
# Processing Record 20 of set 2 | tuktoyaktuk
# Processing Record 21 of set 2 | awjilah
# Processing Record 22 of set 2 | hobart
# Processing Record 23 of set 2 | tucurui
# Processing Record 24 of set 2 | mehamn
# Processing Record 25 of set 2 | valdivia
# Processing Record 26 of set 2 | xai-xai
# Processing Record 27 of set 2 | karakol
# Processing Record 28 of set 2 | lugovoy
# Processing Record 29 of set 2 | aklavik
# Processing Record 30 of set 2 | tura
# Processing Record 31 of set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of set 2 | asmar
# Processing Record 33 of set 2 | kodiak
# Processing Record 34 of set 2 | thompson
# Processing Record 35 of set 2 | ribnica
# Processing Record 36 of set 2 | hithadhoo
# Processing Record 37 of set 2 | ilulissat
# Processing Record 38 of set 2 | virtsu
# Processing Record 39 of set 2 | butaritari
# Processing Record 40 of set 2 | cidreira
# Processing Record 41 of set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of set 2 | tartagal
# Processing Record 43 of set 2 | umm kaddadah
# Processing Record 44 of set 2 | gold coast
# Processing Record 45 of set 2 | yanchukan
# City not found. Skipping...
# Processing Record 46 of set 2 | khairagarh
# Processing Record 47 of set 2 | lewisporte
# Processing Record 48 of set 2 | muncar
# Processing Record 49 of set 2 | yaqui
# Processing Record 50 of set 2 | adrar
# Processing Record 1 of set 3 | kibakwe
# Processing Record 2 of set 3 | halifax
# Processing Record 3 of set 3 | vestmanna
# Processing Record 4 of set 3 | laguna
# Processing Record 5 of set 3 | dikson
# Processing Record 6 of set 3 | hami
# Processing Record 7 of set 3 | saint george
# Processing Record 8 of set 3 | codrington
# Processing Record 9 of set 3 | sorong
# Processing Record 10 of set 3 | ghanzi
# Processing Record 11 of set 3 | hobyo
# Processing Record 12 of set 3 | bredasdorp
# Processing Record 13 of set 3 | pangnirtung
# Processing Record 14 of set 3 | caorle
# Processing Record 15 of set 3 | upernavik
# Processing Record 16 of set 3 | vardo
# Processing Record 17 of set 3 | bend
# Processing Record 18 of set 3 | airai
# Processing Record 19 of set 3 | karratha
# Processing Record 20 of set 3 | mendota
# Processing Record 21 of set 3 | orda
# Processing Record 22 of set 3 | sioux lookout
# Processing Record 23 of set 3 | mbanza-ngungu
# Processing Record 24 of set 3 | rwamagana
# Processing Record 25 of set 3 | vanavara
# Processing Record 26 of set 3 | eureka
# Processing Record 27 of set 3 | poplar bluff
# Processing Record 28 of set 3 | miyako
# Processing Record 29 of set 3 | punta arenas
# Processing Record 30 of set 3 | nome
# Processing Record 31 of set 3 | pevek
# Processing Record 32 of set 3 | zhaocheng
# City not found. Skipping...
# Processing Record 33 of set 3 | hunza
# City not found. Skipping...
# Processing Record 34 of set 3 | cockburn town
# Processing Record 35 of set 3 | ancud
# Processing Record 36 of set 3 | murgab
# Processing Record 37 of set 3 | bethel
# Processing Record 38 of set 3 | marzuq
# Processing Record 39 of set 3 | castro
# Processing Record 40 of set 3 | gimli
# Processing Record 41 of set 3 | temaraia
# City not found. Skipping...
# Processing Record 42 of set 3 | bengkulu
# Processing Record 43 of set 3 | tasbuget
# City not found. Skipping...
# Processing Record 44 of set 3 | tasiilaq
# Processing Record 45 of set 3 | san quintin
# Processing Record 46 of set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of set 3 | machilipatnam
# Processing Record 48 of set 3 | kaitangata
# Processing Record 49 of set 3 | najran
# Processing Record 50 of set 3 | arraial do cabo
# Processing Record 1 of set 4 | verkh-tula
# Processing Record 2 of set 4 | byron bay
# Processing Record 3 of set 4 | toamasina
# Processing Record 4 of set 4 | nouadhibou
# Processing Record 5 of set 4 | karamay
# City not found. Skipping...
# Processing Record 6 of set 4 | cam ranh
# Processing Record 7 of set 4 | bairnsdale
# Processing Record 8 of set 4 | saleaula
# City not found. Skipping...
# Processing Record 9 of set 4 | bereda
# Processing Record 10 of set 4 | victoria
# Processing Record 11 of set 4 | norman wells
# Processing Record 12 of set 4 | kuching
# Processing Record 13 of set 4 | shahr-e babak
# Processing Record 14 of set 4 | mahebourg
# Processing Record 15 of set 4 | wajid
# Processing Record 16 of set 4 | gizo
# Processing Record 17 of set 4 | sedan
# Processing Record 18 of set 4 | waingapu
# Processing Record 19 of set 4 | roebourne
# Processing Record 20 of set 4 | south venice
# Processing Record 21 of set 4 | lasa
# Processing Record 22 of set 4 | agde
# Processing Record 23 of set 4 | narsaq
# Processing Record 24 of set 4 | wewak
# Processing Record 25 of set 4 | jamestown
# Processing Record 26 of set 4 | kargasok
# Processing Record 27 of set 4 | sinnamary
# Processing Record 28 of set 4 | grand gaube
# Processing Record 29 of set 4 | mount isa
# Processing Record 30 of set 4 | ust-kuyga
# Processing Record 31 of set 4 | svetlaya
# Processing Record 32 of set 4 | oktyabrskiy
# Processing Record 33 of set 4 | inuvik
# Processing Record 34 of set 4 | berlevag
# Processing Record 35 of set 4 | tazovskiy
# Processing Record 36 of set 4 | kuruman
# Processing Record 37 of set 4 | adiake
# Processing Record 38 of set 4 | kulhudhuffushi
# Processing Record 39 of set 4 | shakawe
# Processing Record 40 of set 4 | tuatapere
# Processing Record 41 of set 4 | palamos
# Processing Record 42 of set 4 | yar-sale
# Processing Record 43 of set 4 | provideniya
# Processing Record 44 of set 4 | soyo
# Processing Record 45 of set 4 | esperance
# Processing Record 46 of set 4 | krasnyy yar
# Processing Record 47 of set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of set 4 | port elizabeth
# Processing Record 49 of set 4 | zaysan
# Processing Record 50 of set 4 | romulus
# Processing Record 1 of set 5 | beloha
# Processing Record 2 of set 5 | akdagmadeni
# Processing Record 3 of set 5 | touros
# Processing Record 4 of set 5 | flinders
# Processing Record 5 of set 5 | ciudad bolivar
# Processing Record 6 of set 5 | karamea
# City not found. Skipping...
# Processing Record 7 of set 5 | newton
# Processing Record 8 of set 5 | porto novo
# Processing Record 9 of set 5 | maceio
# Processing Record 10 of set 5 | komsomolskiy
# Processing Record 11 of set 5 | coahuayana
# Processing Record 12 of set 5 | nikolskoye
# Processing Record 13 of set 5 | banjar
# Processing Record 14 of set 5 | arona
# Processing Record 15 of set 5 | san cristobal
# Processing Record 16 of set 5 | haines junction
# Processing Record 17 of set 5 | korla
# Processing Record 18 of set 5 | diego de almagro
# Processing Record 19 of set 5 | lagoa
# Processing Record 20 of set 5 | cherskiy
# Processing Record 21 of set 5 | tiksi
# Processing Record 22 of set 5 | manggar
# Processing Record 23 of set 5 | baykit
# Processing Record 24 of set 5 | comodoro rivadavia
# Processing Record 25 of set 5 | rawson
# Processing Record 26 of set 5 | kuche
# City not found. Skipping...
# Processing Record 27 of set 5 | hamilton
# Processing Record 28 of set 5 | barentsburg
# City not found. Skipping...
# Processing Record 29 of set 5 | bambous virieux
# Processing Record 30 of set 5 | cap malheureux
# Processing Record 31 of set 5 | kuytun
# Processing Record 32 of set 5 | basoko
# Processing Record 33 of set 5 | ucluelet
# Processing Record 34 of set 5 | masunga
# Processing Record 35 of set 5 | xghajra
# City not found. Skipping...
# Processing Record 36 of set 5 | apen
# Processing Record 37 of set 5 | pontianak
# Processing Record 38 of set 5 | aketi
# Processing Record 39 of set 5 | saskylakh
# Processing Record 40 of set 5 | constitucion
# Processing Record 41 of set 5 | manamadurai
# Processing Record 42 of set 5 | warwick
# Processing Record 43 of set 5 | atbasar
# Processing Record 44 of set 5 | wexford
# Processing Record 45 of set 5 | asau
# Processing Record 46 of set 5 | juneau
# Processing Record 47 of set 5 | atherton
# Processing Record 48 of set 5 | souillac
# Processing Record 49 of set 5 | guerrero negro
# Processing Record 50 of set 5 | karagay
# Processing Record 1 of set 6 | kamaishi
# Processing Record 2 of set 6 | margate
# Processing Record 3 of set 6 | oriximina
# Processing Record 4 of set 6 | itaperucu
# Processing Record 5 of set 6 | solnechnyy
# Processing Record 6 of set 6 | viedma
# Processing Record 7 of set 6 | chokurdakh
# Processing Record 8 of set 6 | posse
# Processing Record 9 of set 6 | czersk
# Processing Record 10 of set 6 | abalak
# Processing Record 11 of set 6 | nola
# Processing Record 12 of set 6 | kondopoga
# Processing Record 13 of set 6 | nyrob
# Processing Record 14 of set 6 | penapolis
# Processing Record 15 of set 6 | galgani
# City not found. Skipping...
# Processing Record 16 of set 6 | nanortalik
# Processing Record 17 of set 6 | half moon bay
# Processing Record 18 of set 6 | rincon
# Processing Record 19 of set 6 | coihaique
# Processing Record 20 of set 6 | seymchan
# Processing Record 21 of set 6 | el silencio
# Processing Record 22 of set 6 | luderitz
# Processing Record 23 of set 6 | sola
# Processing Record 24 of set 6 | keti bandar
# Processing Record 25 of set 6 | vinh
# Processing Record 26 of set 6 | warmbad
# Processing Record 27 of set 6 | warqla
# City not found. Skipping...
# Processing Record 28 of set 6 | kruisfontein
# Processing Record 29 of set 6 | cameta
# Processing Record 30 of set 6 | aksarka
# Processing Record 31 of set 6 | chernyshevskiy
# Processing Record 32 of set 6 | matay
# Processing Record 33 of set 6 | tadine
# Processing Record 34 of set 6 | ornskoldsvik
# Processing Record 35 of set 6 | san pedro
# Processing Record 36 of set 6 | mwaro
# Processing Record 37 of set 6 | ponta do sol
# Processing Record 38 of set 6 | clyde river
# Processing Record 39 of set 6 | sakti
# Processing Record 40 of set 6 | buraydah
# Processing Record 41 of set 6 | tuensang
# Processing Record 42 of set 6 | pisco
# Processing Record 43 of set 6 | waipawa
# Processing Record 44 of set 6 | padang
# Processing Record 45 of set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of set 6 | concarneau
# Processing Record 47 of set 6 | tucuma
# Processing Record 48 of set 6 | macaboboni
# City not found. Skipping...
# Processing Record 49 of set 6 | makakilo city
# Processing Record 50 of set 6 | bandarbeyla
# Processing Record 1 of set 7 | boyabat
# Processing Record 2 of set 7 | kleck
# City not found. Skipping...
# Processing Record 3 of set 7 | sitka
# Processing Record 4 of set 7 | lolua
# City not found. Skipping...
# Processing Record 5 of set 7 | senmonorom
# City not found. Skipping...
# Processing Record 6 of set 7 | lorengau
# Processing Record 7 of set 7 | prado
# Processing Record 8 of set 7 | khorixas
# Processing Record 9 of set 7 | verkhnevilyuysk
# Processing Record 10 of set 7 | askiz
# Processing Record 11 of set 7 | alofi
# Processing Record 12 of set 7 | ourem
# Processing Record 13 of set 7 | marawi
# Processing Record 14 of set 7 | kahului
# Processing Record 15 of set 7 | torbay
# Processing Record 16 of set 7 | shimoda
# Processing Record 17 of set 7 | santa luzia
# Processing Record 18 of set 7 | coquimbo
# Processing Record 19 of set 7 | labuhan
# Processing Record 20 of set 7 | saint anthony
# Processing Record 21 of set 7 | nisia floresta
# Processing Record 22 of set 7 | acatlan
# Processing Record 23 of set 7 | severo-kurilsk
# Processing Record 24 of set 7 | pangody
# Processing Record 25 of set 7 | olafsvik
# Processing Record 26 of set 7 | sao filipe
# Processing Record 27 of set 7 | xuanhua
# Processing Record 28 of set 7 | marcona
# City not found. Skipping...
# Processing Record 29 of set 7 | vaitupu
# City not found. Skipping...
# Processing Record 30 of set 7 | chanute
# Processing Record 31 of set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of set 7 | tondano
# Processing Record 33 of set 7 | khonuu
# City not found. Skipping...
# Processing Record 34 of set 7 | mahanoro
# Processing Record 35 of set 7 | khilok
# Processing Record 36 of set 7 | port lincoln
# Processing Record 37 of set 7 | ribeira grande
# Processing Record 38 of set 7 | hambantota
# Processing Record 39 of set 7 | saint-georges
# Processing Record 40 of set 7 | novyy rogachik
# Processing Record 41 of set 7 | tevaitoa
# Processing Record 42 of set 7 | vila franca do campo
# Processing Record 43 of set 7 | pokhara
# Processing Record 44 of set 7 | faya
# Processing Record 45 of set 7 | nishihara
# Processing Record 46 of set 7 | batticaloa
# Processing Record 47 of set 7 | port hardy
# Processing Record 48 of set 7 | charters towers
# Processing Record 49 of set 7 | esna
# Processing Record 50 of set 7 | takoradi
# Processing Record 1 of set 8 | husavik
# Processing Record 2 of set 8 | thai binh
# Processing Record 3 of set 8 | cam pha
# City not found. Skipping...
# Processing Record 4 of set 8 | kailaras
# Processing Record 5 of set 8 | ribas do rio pardo
# Processing Record 6 of set 8 | jarjis
# City not found. Skipping...
# Processing Record 7 of set 8 | rothesay
# Processing Record 8 of set 8 | suba
# Processing Record 9 of set 8 | burtunay
# Processing Record 10 of set 8 | yulara
# Processing Record 11 of set 8 | leningradskiy
# Processing Record 12 of set 8 | vila
# Processing Record 13 of set 8 | buala
# Processing Record 14 of set 8 | kabwe
# Processing Record 15 of set 8 | togul
# Processing Record 16 of set 8 | oktyabrskoye
# Processing Record 17 of set 8 | opotiki
# Processing Record 18 of set 8 | rockport
# Processing Record 19 of set 8 | marica
# Processing Record 20 of set 8 | goksun
# Processing Record 21 of set 8 | phuket
# Processing Record 22 of set 8 | akyab
# Processing Record 23 of set 8 | condoto
# Processing Record 24 of set 8 | lavrentiya
# Processing Record 25 of set 8 | zhezkazgan
# Processing Record 26 of set 8 | port blair
# Processing Record 27 of set 8 | putina
# Processing Record 28 of set 8 | lusambo
# Processing Record 29 of set 8 | jerusalem
# Processing Record 30 of set 8 | sobolevo
# Processing Record 31 of set 8 | reconquista
# Processing Record 32 of set 8 | port macquarie
# Processing Record 33 of set 8 | mayor pablo lagerenza
# Processing Record 34 of set 8 | bilma
# Processing Record 35 of set 8 | darab
# Processing Record 36 of set 8 | nara
# Processing Record 37 of set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of set 8 | cervo
# Processing Record 39 of set 8 | vestmannaeyjar
# Processing Record 40 of set 8 | tabou
# Processing Record 41 of set 8 | irbeyskoye
# Processing Record 42 of set 8 | chuy
# Processing Record 43 of set 8 | wum
# Processing Record 44 of set 8 | waterloo
# Processing Record 45 of set 8 | barcelos
# Processing Record 46 of set 8 | gobabis
# Processing Record 47 of set 8 | djambala
# Processing Record 48 of set 8 | la vega
# Processing Record 49 of set 8 | hella
# Processing Record 50 of set 8 | mount gambier
# Processing Record 1 of set 9 | qingdao
# Processing Record 2 of set 9 | payo
# Processing Record 3 of set 9 | te anau
# Processing Record 4 of set 9 | vilyuysk
# Processing Record 5 of set 9 | bjornevatn
# Processing Record 6 of set 9 | la ronge
# Processing Record 7 of set 9 | leh
# Processing Record 8 of set 9 | maneadero
# Processing Record 9 of set 9 | isangel
# Processing Record 10 of set 9 | port-cartier
# Processing Record 11 of set 9 | almaznyy
# Processing Record 12 of set 9 | chilac
# City not found. Skipping...
# Processing Record 13 of set 9 | tual
# Processing Record 14 of set 9 | bireun
# Processing Record 15 of set 9 | sisimiut
# Processing Record 16 of set 9 | poya
# Processing Record 17 of set 9 | college
# Processing Record 18 of set 9 | san jose
# Processing Record 19 of set 9 | omsukchan
# Processing Record 20 of set 9 | longhua
# Processing Record 21 of set 9 | obihiro
# Processing Record 22 of set 9 | namtsy
# Processing Record 23 of set 9 | fairbanks
# Processing Record 24 of set 9 | keflavik
# Processing Record 25 of set 9 | yumen
# Processing Record 26 of set 9 | ambon
# Processing Record 27 of set 9 | derzhavinsk
# Processing Record 28 of set 9 | wenling
# Processing Record 29 of set 9 | bage
# Processing Record 30 of set 9 | bantogon
# Processing Record 31 of set 9 | rungata
# City not found. Skipping...
# Processing Record 32 of set 9 | taltal
# Processing Record 33 of set 9 | klaksvik
# Processing Record 34 of set 9 | orotukan
# Processing Record 35 of set 9 | pitimbu
# Processing Record 36 of set 9 | yangambi
# Processing Record 37 of set 9 | jalu
# Processing Record 38 of set 9 | okhotsk
# Processing Record 39 of set 9 | dickinson
# Processing Record 40 of set 9 | west plains
# Processing Record 41 of set 9 | san rafael
# Processing Record 42 of set 9 | henties bay
# Processing Record 43 of set 9 | kununurra
# Processing Record 44 of set 9 | atambua
# Processing Record 45 of set 9 | pilar
# Processing Record 46 of set 9 | hasanpur
# Processing Record 47 of set 9 | vila velha
# Processing Record 48 of set 9 | tessalit
# Processing Record 49 of set 9 | rocha
# Processing Record 50 of set 9 | toliary
# City not found. Skipping...
# Processing Record 1 of set 10 | baghmara
# Processing Record 2 of set 10 | vanderhoof
# Processing Record 3 of set 10 | inhambane
# Processing Record 4 of set 10 | camacha
# Processing Record 5 of set 10 | abu dhabi
# Processing Record 6 of set 10 | shenjiamen
# Processing Record 7 of set 10 | sakakah
# Processing Record 8 of set 10 | tivaouane
# Processing Record 9 of set 10 | ye
# City not found. Skipping...
# Processing Record 10 of set 10 | chililabombwe
# Processing Record 11 of set 10 | samarai
# Processing Record 12 of set 10 | aranos
# Processing Record 13 of set 10 | faanui
# Processing Record 14 of set 10 | leczyca
# Processing Record 15 of set 10 | jeremie
# Processing Record 16 of set 10 | vitim
# Processing Record 17 of set 10 | kodinsk
# Processing Record 18 of set 10 | kazachinskoye
# Processing Record 19 of set 10 | galiwinku
# City not found. Skipping...
# Processing Record 20 of set 10 | tumannyy
# City not found. Skipping...
# Processing Record 21 of set 10 | carbonia
# Processing Record 22 of set 10 | storforshei
# Processing Record 23 of set 10 | meulaboh
# Processing Record 24 of set 10 | valparaiso
# Processing Record 25 of set 10 | labutta
# City not found. Skipping...
# Processing Record 26 of set 10 | lufilufi
# Processing Record 27 of set 10 | kracheh
# City not found. Skipping...
# Processing Record 28 of set 10 | pacific grove
# Processing Record 29 of set 10 | turukhansk
# Processing Record 30 of set 10 | campoverde
# Processing Record 31 of set 10 | sur
# Processing Record 32 of set 10 | farmersville
# Processing Record 33 of set 10 | logansport
# Processing Record 34 of set 10 | strezhevoy
# Processing Record 35 of set 10 | moose factory
# Processing Record 36 of set 10 | gushikawa
# Processing Record 37 of set 10 | iqaluit
# Processing Record 38 of set 10 | slave lake
# Processing Record 39 of set 10 | ndjole
# Processing Record 40 of set 10 | ust-kulom
# Processing Record 41 of set 10 | lucatan
# City not found. Skipping...
# Processing Record 42 of set 10 | taunggyi
# Processing Record 43 of set 10 | tobane
# Processing Record 44 of set 10 | launceston
# Processing Record 45 of set 10 | martapura
# Processing Record 46 of set 10 | odesskoye
# Processing Record 47 of set 10 | brewster
# Processing Record 48 of set 10 | ishigaki
# Processing Record 49 of set 10 | rurrenabaque
# Processing Record 50 of set 10 | broken hill
# Processing Record 1 of set 11 | bonavista
# Processing Record 2 of set 11 | xambioa
# Processing Record 3 of set 11 | binzhou
# Processing Record 4 of set 11 | monrovia
# Processing Record 5 of set 11 | beian
# Processing Record 6 of set 11 | kalabo
# Processing Record 7 of set 11 | bowen
# Processing Record 8 of set 11 | mackenzie
# Processing Record 9 of set 11 | kaberamaido
# Processing Record 10 of set 11 | otane
# Processing Record 11 of set 11 | panji
# Processing Record 12 of set 11 | baie-comeau
# Processing Record 13 of set 11 | pasni
# Processing Record 14 of set 11 | geraldton
# Processing Record 15 of set 11 | chapais
# Processing Record 16 of set 11 | mackay
# Processing Record 17 of set 11 | oussouye
# Processing Record 18 of set 11 | namibe
# Processing Record 19 of set 11 | hirara
# Processing Record 20 of set 11 | nelson bay
# Processing Record 21 of set 11 | aguimes
# Processing Record 22 of set 11 | antalaha
# Processing Record 23 of set 11 | ilave
# Processing Record 24 of set 11 | hulshout
# Processing Record 25 of set 11 | sao joao da barra
# Processing Record 26 of set 11 | palmer
# Processing Record 27 of set 11 | kenora
# Processing Record 28 of set 11 | khovu-aksy
# Processing Record 29 of set 11 | gamba
# Processing Record 30 of set 11 | harindanga
# Processing Record 31 of set 11 | guelavia
# City not found. Skipping...
# Processing Record 32 of set 11 | seoul
# Processing Record 33 of set 11 | srednekolymsk
# Processing Record 34 of set 11 | lahaina
# Processing Record 35 of set 11 | salinopolis
# Processing Record 36 of set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of set 11 | longyearbyen
# Processing Record 38 of set 11 | bengkalis
# City not found. Skipping...
# Processing Record 39 of set 11 | hovd
# Processing Record 40 of set 11 | cumaribo
# City not found. Skipping...
# Processing Record 41 of set 11 | rio cuarto
# Processing Record 42 of set 11 | zambezi
# Processing Record 43 of set 11 | amderma
# City not found. Skipping...
# Processing Record 44 of set 11 | muros
# Processing Record 45 of set 11 | maryville
# Processing Record 46 of set 11 | qasigiannguit
# Processing Record 47 of set 11 | moranbah
# Processing Record 48 of set 11 | san pedro de lloc
# Processing Record 49 of set 11 | pangai
# Processing Record 50 of set 11 | shpykiv
# City not found. Skipping...
# Processing Record 1 of set 12 | kieta
# Processing Record 2 of set 12 | grand river south east
# City not found. Skipping...
# Processing Record 3 of set 12 | mbandaka
# Processing Record 4 of set 12 | adelaide
# Processing Record 5 of set 12 | zharkent
# Processing Record 6 of set 12 | kirakira
# Processing Record 7 of set 12 | nizwa
# Processing Record 8 of set 12 | riyadh
# Processing Record 9 of set 12 | christchurch
# Processing Record 10 of set 12 | sangar
# Processing Record 11 of set 12 | impfondo
# Processing Record 12 of set 12 | pimentel
# Processing Record 13 of set 12 | abnub
# Processing Record 14 of set 12 | angoche
# Processing Record 15 of set 12 | sovetskiy
# Processing Record 16 of set 12 | brigantine
# Processing Record 17 of set 12 | imeni poliny osipenko
# Processing Record 18 of set 12 | gwanda
# Processing Record 19 of set 12 | lucea
# Processing Record 20 of set 12 | feijo
# Processing Record 21 of set 12 | lata
# Processing Record 22 of set 12 | nong phai
# Processing Record 23 of set 12 | orange cove
# Processing Record 24 of set 12 | bonthe
# Processing Record 25 of set 12 | nemuro
# Processing Record 26 of set 12 | taicheng
# Processing Record 27 of set 12 | anjiang
# Processing Record 28 of set 12 | santiago de cao
# Processing Record 29 of set 12 | muravlenko
# Processing Record 30 of set 12 | palauig
# Processing Record 31 of set 12 | hualmay
# Processing Record 32 of set 12 | george town
# Processing Record 33 of set 12 | sassandra
# Processing Record 34 of set 12 | kalmunai
# Processing Record 35 of set 12 | buon me thuot
# City not found. Skipping...
# Processing Record 36 of set 12 | bubaque
# Processing Record 37 of set 12 | manzhouli
# Processing Record 38 of set 12 | ingham
# Processing Record 39 of set 12 | khasan
# Processing Record 40 of set 12 | kiama
# Processing Record 41 of set 12 | jijiga
# Processing Record 42 of set 12 | romanovskaya
# Processing Record 43 of set 12 | olinda
# Processing Record 44 of set 12 | kutum
# Processing Record 45 of set 12 | pringsewu
# Processing Record 46 of set 12 | assens
# Processing Record 47 of set 12 | kushmurun
# Processing Record 48 of set 12 | grindavik
# Processing Record 49 of set 12 | uvira
# Processing Record 50 of set 12 | itarema
# Processing Record 1 of set 13 | zatoka
# Processing Record 2 of set 13 | alotau
# City not found. Skipping...
# Processing Record 3 of set 13 | muswellbrook
# Processing Record 4 of set 13 | blois
# Processing Record 5 of set 13 | barlinek
# Processing Record 6 of set 13 | union city
# Processing Record 7 of set 13 | waiouru
# Processing Record 8 of set 13 | dumas
# Processing Record 9 of set 13 | quelimane
# Processing Record 10 of set 13 | virginia beach
# Processing Record 11 of set 13 | alta floresta
# Processing Record 12 of set 13 | sarangani
# Processing Record 13 of set 13 | morondava
# Processing Record 14 of set 13 | ketchikan
# Processing Record 15 of set 13 | nouakchott
# Processing Record 16 of set 13 | chase
# Processing Record 17 of set 13 | san ignacio
# Processing Record 18 of set 13 | kyabram
# Processing Record 19 of set 13 | cacu
# Processing Record 20 of set 13 | negara
# Processing Record 21 of set 13 | oxelosund
# Processing Record 22 of set 13 | maniitsoq
# Processing Record 23 of set 13 | wonthaggi
# Processing Record 24 of set 13 | talaya
# Processing Record 25 of set 13 | harper
# -----------------------------
#    Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 570

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona  -9.8000 -139.0333     78.80        74           7
# 1       Ushuaia -54.8000  -68.3000     42.46        70          40
# 2   Santa Maria -29.6842  -53.8069     71.51        58           0
# 3       Kavieng  -2.5744  150.7967     82.31        72         100
# 4  Puerto Ayora  -0.7393  -90.3518     74.55        96         100
# 5      Khatanga  71.9667  102.5000    -38.04        99          28
# 6          Suez  29.9737   32.5263     53.80        64           0
# 7        Barrow  71.2906 -156.7887    -16.58        69          40
# 8       Rikitea -23.1203 -134.9692     78.40        69          90
# 9  San Patricio  28.0170  -97.5169     61.90        82          13
#
#    Wind Speed Country                   Date
# 0       17.69      PF  2022-02-02   03:13:42
# 1       33.38      AR  2022-02-02   03:13:14
# 2        6.76      BR  2022-02-02   03:13:42
# 3        6.91      PG  2022-02-02   03:13:42
# 4        5.01      EC  2022-02-02   03:13:43
# 5        2.30      RU  2022-02-02   03:13:43
# 6        5.59      EG  2022-02-02   03:13:43
# 7       10.36      US  2022-02-02   03:13:35
# 8        4.99      PF  2022-02-02   03:09:59
# 9        7.63      US  2022-02-02   03:13:44

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
                    
city_data_df = city_data_df[new_column_order]
                    
city_data_df.head(10)
# Out:
#            City Country                   Date      Lat       Lng  Max Temp  \
# 0        Atuona      PF  2022-02-02   03:13:42  -9.8000 -139.0333     78.80
# 1       Ushuaia      AR  2022-02-02   03:13:14 -54.8000  -68.3000     42.46
# 2   Santa Maria      BR  2022-02-02   03:13:42 -29.6842  -53.8069     71.51
# 3       Kavieng      PG  2022-02-02   03:13:42  -2.5744  150.7967     82.31
# 4  Puerto Ayora      EC  2022-02-02   03:13:43  -0.7393  -90.3518     74.55
# 5      Khatanga      RU  2022-02-02   03:13:43  71.9667  102.5000    -38.04
# 6          Suez      EG  2022-02-02   03:13:43  29.9737   32.5263     53.80
# 7        Barrow      US  2022-02-02   03:13:35  71.2906 -156.7887    -16.58
# 8       Rikitea      PF  2022-02-02   03:09:59 -23.1203 -134.9692     78.40
# 9  San Patricio      US  2022-02-02   03:13:44  28.0170  -97.5169     61.90
#
#    Humidity  Cloudiness  Wind Speed
# 0        74           7       17.69
# 1        70          40       33.38
# 2        58           0        6.76
# 3        72         100        6.91
# 4        96         100        5.01
# 5        99          28        2.30
# 6        64           0        5.59
# 7        69          40       10.36
# 8        69          90        4.99
# 9        82          13        7.63

# %%
# Create the output file (CSV)
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature
plt.scatter(lats, max_temps, 
           edgecolor = "black", linewidths = 1, marker = "o", 
           alpha = 0.8, label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity
plt.scatter(lats, humidity, 
           edgecolor = "black", linewidths = 1, marker = "o", 
           alpha = 0.8, label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. cloudiness
plt.scatter(lats, cloudiness, 
           edgecolor = "black", linewidths = 1, marker = "o", 
           alpha = 0.8, label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. wind speed
plt.scatter(lats, wind_speed, 
           edgecolor = "black", linewidths = 1, marker = "o", 
           alpha = 0.8, label = "Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("weather_data/Fig4.png")

# Show plot
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to perform linear regression on the weather data and plot a regression line and the equation
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regress on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    # Create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    # Annotate the text for the line equation
    plt.annotate(line_eq, text_coordinates, fontsize = 15, color = "red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                          Manta
# Country                          EC
# Date          2022-02-02   03:13:45
# Lat                           -0.95
# Lng                        -80.7333
# Max Temp                      76.78
# Humidity                         88
# Cloudiness                       75
# Wind Speed                     1.14
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >=0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 565     True
# 566     True
# 567    False
# 568     True
# 569     True
# Name: Lat, Length: 570, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#             City Country                   Date      Lat       Lng  Max Temp  \
# 5       Khatanga      RU  2022-02-02   03:13:43  71.9667  102.5000    -38.04
# 6           Suez      EG  2022-02-02   03:13:43  29.9737   32.5263     53.80
# 7         Barrow      US  2022-02-02   03:13:35  71.2906 -156.7887    -16.58
# 9   San Patricio      US  2022-02-02   03:13:44  28.0170  -97.5169     61.90
# 11      Hargeysa      SO  2022-02-02   03:13:44   9.5600   44.0650     58.53
#
#     Humidity  Cloudiness  Wind Speed
# 5         99          28        2.30
# 6         64           0        5.59
# 7         69          40       10.36
# 9         82          13        7.63
# 11        94          99       13.67

# %%
# Create northern and southern hemisphere dataframes
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Northern Hemisphere for Maximum Temperature",
                      "Max Temp",(5, -20))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Southern Hemisphere for Maximum Temperature",
                      "Max Temp",(-50, 45))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Northern Hemisphere for % Humidity",
                      "Humidity",(40, 10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Southern Hemisphere for % Humidity",
                      "Humidity",(-25, 15))

# %%
# Skill Drill 6.4.4
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Northern Hemisphere for % Cloudiness",
                      "% Cloudiness",(50, 5))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Southern Hemisphere for % Cloudiness",
                      "% Cloudiness",(-55, 20))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Northern Hemisphere for Wind Speed",
                      "%Wind Speed (mph)",(45, 30))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Call the function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Southern Hemisphere for Wind Speed",
                      "%Wind Speed (mph)",(-55, 30))
